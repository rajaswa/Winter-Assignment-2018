# %% [markdown]
# # Preparing the Data

# %%
import numpy as np
import os
import string

# %%
reviews = []

# load doc into memory
def load_doc(filename):
    # open the file as read only
    file = open(filename, 'r')
    # read all text
    text = file.read()
    # close the file
    file.close()
    return text
 
# specify directories to load
directories = ['aclImdb/train/pos', 'aclImdb/train/neg', 'aclImdb/test/pos', 'aclImdb/test/neg']

# walk through all files in the folder
for directory in directories:
    for filename in os.listdir(directory):
        # skip files that do not have the right extension
        if not filename.endswith(".txt"):
            continue
        # create the full path of the file to open
        path = directory + '/' + filename
        # load document
        doc = load_doc(path)
        reviews.append(doc)
        print('Loaded %s' % filename)
# Out:
# Loaded 4268_10.txt
# Loaded 6798_9.txt
# Loaded 2675_9.txt
# Loaded 11060_10.txt
# Loaded 9084_7.txt
# Loaded 8447_8.txt
# Loaded 10297_8.txt
# Loaded 2794_8.txt
# Loaded 9509_9.txt
# Loaded 3635_9.txt
# Loaded 2021_8.txt
# Loaded 3377_8.txt
# Loaded 61_10.txt
# Loaded 8998_10.txt
# Loaded 3994_8.txt
# Loaded 8620_8.txt
# Loaded 9105_9.txt
# Loaded 1434_10.txt
# Loaded 1174_10.txt
# Loaded 4706_8.txt
# Loaded 10971_9.txt
# Loaded 5119_10.txt
# Loaded 2917_7.txt
# Loaded 12413_9.txt
# Loaded 5213_8.txt
# Loaded 721_10.txt
# Loaded 680_8.txt
# Loaded 798_10.txt
# Loaded 6030_10.txt
# Loaded 5686_9.txt
# Loaded 5661_10.txt
# Loaded 5919_9.txt
# Loaded 3170_9.txt
# Loaded 9540_8.txt
# Loaded 6965_7.txt
# Loaded 1490_8.txt
# Loaded 12391_9.txt
# Loaded 1758_10.txt
# Loaded 4493_9.txt
# Loaded 2835_7.txt
# Loaded 8926_10.txt
# Loaded 378_8.txt
# Loaded 3729_10.txt
# Loaded 1811_10.txt
# Loaded 3624_10.txt
# Loaded 3716_9.txt
# Loaded 6038_10.txt
# Loaded 2030_9.txt
# Loaded 4126_8.txt
# Loaded 4351_10.txt
# Loaded 3482_10.txt
# Loaded 4823_7.txt
# Loaded 10642_8.txt
# Loaded 11405_8.txt
# Loaded 3081_9.txt
# Loaded 3101_9.txt
# Loaded 1883_7.txt
# Loaded 573_9.txt
# Loaded 3359_10.txt
# Loaded 6467_7.txt
# Loaded 4639_10.txt
# Loaded 5139_9.txt
# Loaded 7358_10.txt
# Loaded 9542_10.txt
# Loaded 9586_10.txt
# Loaded 8379_10.txt
# Loaded 7434_7.txt
# Loaded 534_10.txt
# Loaded 3259_7.txt
# Loaded 6599_8.txt
# Loaded 7197_7.txt
# Loaded 4553_10.txt
# Loaded 4247_10.txt
# Loaded 6588_9.txt
# Loaded 6702_8.txt
# Loaded 1044_8.txt
# Loaded 7134_10.txt
# Loaded 570_10.txt
# Loaded 10104_10.txt
# Loaded 7254_10.txt
# Loaded 10889_10.txt
# Loaded 7279_9.txt
# Loaded 10669_10.txt
# Loaded 8617_9.txt
# Loaded 1841_7.txt
# Loaded 4352_10.txt
# Loaded 9460_8.txt
# Loaded 6813_10.txt
# Loaded 4561_10.txt
# Loaded 10748_10.txt
# Loaded 4587_10.txt
# Loaded 1008_10.txt
# Loaded 5691_8.txt
# Loaded 6745_8.txt
# Loaded 4387_9.txt
# Loaded 11909_7.txt
# Loaded 12345_10.txt
# Loaded 7399_10.txt
# Loaded 11106_10.txt
# Loaded 8522_10.txt
# Loaded 472_10.txt
# Loaded 8681_8.txt
# Loaded 10341_7.txt
# Loaded 4113_7.txt
# Loaded 7175_10.txt
# Loaded 5254_9.txt
# Loaded 10009_9.txt
# Loaded 12295_9.txt
# Loaded 4476_9.txt
# Loaded 11913_10.txt
# Loaded 1080_9.txt
# Loaded 7304_8.txt
# Loaded 7606_9.txt
# Loaded 5310_10.txt
# Loaded 3568_7.txt
# Loaded 6144_7.txt
# Loaded 7831_8.txt
# Loaded 4430_8.txt
# Loaded 1838_10.txt
# Loaded 310_7.txt
# Loaded 3981_10.txt
# Loaded 10998_7.txt
# Loaded 505_9.txt
# Loaded 5062_9.txt
# Loaded 7854_10.txt
# Loaded 8407_7.txt
# Loaded 1716_8.txt
# Loaded 3733_10.txt
# Loaded 2623_7.txt
# Loaded 5925_7.txt
# Loaded 2814_10.txt
# Loaded 8908_10.txt
# Loaded 11175_8.txt
# Loaded 4839_10.txt
# Loaded 6160_10.txt
# Loaded 1022_10.txt
# Loaded 3132_9.txt
# Loaded 1431_10.txt
# Loaded 7073_10.txt
# Loaded 2694_10.txt
# Loaded 11489_10.txt
# Loaded 7296_10.txt
# Loaded 6399_7.txt
# Loaded 6368_7.txt
# Loaded 4979_10.txt
# Loaded 9371_7.txt
# Loaded 482_8.txt
# Loaded 2981_10.txt
# Loaded 8914_8.txt
# Loaded 333_10.txt
# Loaded 9308_7.txt
# Loaded 8713_10.txt
# Loaded 7674_10.txt
# Loaded 1348_10.txt
# Loaded 12424_9.txt
# Loaded 1852_9.txt
# Loaded 1655_8.txt
# Loaded 301_10.txt
# Loaded 11685_8.txt
# Loaded 8535_7.txt
# Loaded 9786_8.txt
# Loaded 7453_10.txt
# Loaded 9813_8.txt
# Loaded 8514_7.txt
# Loaded 8418_7.txt
# Loaded 12130_7.txt
# Loaded 8555_9.txt
# Loaded 3125_10.txt
# Loaded 3770_10.txt
# Loaded 151_10.txt
# Loaded 2595_9.txt
# Loaded 443_10.txt
# Loaded 11173_7.txt
# Loaded 11955_7.txt
# Loaded 10641_7.txt
# Loaded 9260_7.txt
# Loaded 10349_10.txt
# Loaded 12166_10.txt
# Loaded 10882_8.txt
# Loaded 11002_8.txt
# Loaded 2706_9.txt
# Loaded 1837_10.txt
# Loaded 9275_9.txt
# Loaded 1574_9.txt
# Loaded 11808_9.txt
# Loaded 2807_7.txt
# Loaded 4601_7.txt
# Loaded 4224_10.txt
# Loaded 2686_9.txt
# Loaded 12370_8.txt
# Loaded 2545_8.txt
# Loaded 3802_10.txt
# Loaded 10248_7.txt
# Loaded 954_10.txt
# Loaded 3052_10.txt
# Loaded 2662_10.txt
# Loaded 10371_8.txt
# Loaded 4499_9.txt
# Loaded 6760_9.txt
# Loaded 4232_7.txt
# Loaded 3524_9.txt
# Loaded 2412_10.txt
# Loaded 322_10.txt
# Loaded 10500_10.txt
# Loaded 6627_7.txt
# Loaded 5810_9.txt
# Loaded 8156_10.txt
# Loaded 3047_7.txt
# Loaded 11072_8.txt
# Loaded 9987_9.txt
# Loaded 11695_9.txt
# Loaded 1293_8.txt
# Loaded 775_7.txt
# Loaded 5741_10.txt
# Loaded 6307_8.txt
# Loaded 3599_8.txt
# Loaded 2347_10.txt
# Loaded 4107_10.txt
# Loaded 11258_8.txt
# Loaded 11287_8.txt
# Loaded 10477_9.txt
# Loaded 8631_7.txt
# Loaded 8145_10.txt
# Loaded 7307_10.txt
# Loaded 7171_10.txt
# Loaded 2990_10.txt
# Loaded 9739_7.txt
# Loaded 11520_8.txt
# Loaded 12272_7.txt
# Loaded 2863_8.txt
# Loaded 3740_9.txt
# Loaded 4733_9.txt
# Loaded 1269_8.txt
# Loaded 9306_9.txt
# Loaded 7844_10.txt
# Loaded 1750_10.txt
# Loaded 3774_8.txt
# Loaded 12038_9.txt
# Loaded 9212_9.txt
# Loaded 7711_10.txt
# Loaded 8369_8.txt
# Loaded 8340_8.txt
# Loaded 9949_9.txt
# Loaded 1937_10.txt
# Loaded 11394_10.txt
# Loaded 5307_7.txt
# Loaded 949_8.txt
# Loaded 10278_7.txt
# Loaded 3367_9.txt
# Loaded 4266_7.txt
# Loaded 2683_10.txt
# Loaded 6023_8.txt
# Loaded 7706_7.txt
# Loaded 6873_10.txt
# Loaded 3884_8.txt
# Loaded 9798_7.txt
# Loaded 12209_7.txt
# Loaded 2336_10.txt
# Loaded 4412_9.txt
# Loaded 149_10.txt
# Loaded 6195_10.txt
# Loaded 9408_10.txt
# Loaded 1559_7.txt
# Loaded 5235_8.txt
# Loaded 848_8.txt
# Loaded 7792_10.txt
# Loaded 8787_8.txt
# Loaded 11088_7.txt
# Loaded 12235_7.txt
# Loaded 6037_10.txt
# Loaded 11925_7.txt
# Loaded 8813_9.txt
# Loaded 3555_7.txt
# Loaded 7751_7.txt
# Loaded 3089_9.txt
# Loaded 8694_10.txt
# Loaded 6552_9.txt
# Loaded 5029_8.txt
# Loaded 8708_8.txt
# Loaded 10650_8.txt
# Loaded 4213_7.txt
# Loaded 3363_10.txt
# Loaded 4017_7.txt
# Loaded 3172_9.txt
# Loaded 9425_10.txt
# Loaded 6131_10.txt
# Loaded 8087_8.txt
# Loaded 11022_9.txt
# Loaded 7479_8.txt
# Loaded 6587_9.txt
# Loaded 7978_8.txt
# Loaded 4310_9.txt
# Loaded 1140_10.txt
# Loaded 10142_8.txt
# Loaded 2162_10.txt
# Loaded 10978_10.txt
# Loaded 420_7.txt
# Loaded 6983_8.txt
# Loaded 9060_8.txt
# Loaded 8264_9.txt
# Loaded 1160_10.txt
# Loaded 3283_8.txt
# Loaded 12274_10.txt
# Loaded 5795_10.txt
# Loaded 9115_10.txt
# Loaded 3834_9.txt
# Loaded 8654_9.txt
# Loaded 7756_10.txt
# Loaded 7901_7.txt
# Loaded 4516_10.txt
# Loaded 5977_8.txt
# Loaded 10725_9.txt
# Loaded 7265_8.txt
# Loaded 11035_8.txt
# Loaded 755_10.txt
# Loaded 10075_9.txt
# Loaded 4778_9.txt
# Loaded 9838_7.txt
# Loaded 4714_10.txt
# Loaded 12388_8.txt
# Loaded 2344_9.txt
# Loaded 9928_7.txt
# Loaded 4496_8.txt
# Loaded 12477_10.txt
# Loaded 6495_10.txt
# Loaded 6088_10.txt
# Loaded 3821_9.txt
# Loaded 1865_8.txt
# Loaded 1281_10.txt
# Loaded 11658_10.txt
# Loaded 5214_7.txt
# Loaded 7054_9.txt
# Loaded 5495_8.txt
# Loaded 3026_7.txt
# Loaded 11956_9.txt
# Loaded 11166_7.txt
# Loaded 1864_10.txt
# Loaded 9091_10.txt
# Loaded 7704_10.txt
# Loaded 9664_10.txt
# Loaded 12249_8.txt
# Loaded 3177_9.txt
# Loaded 4869_10.txt
# Loaded 4534_9.txt
# Loaded 6706_8.txt
# Loaded 10768_7.txt
# Loaded 6147_7.txt
# Loaded 12375_7.txt
# Loaded 7090_10.txt
# Loaded 2447_10.txt
# Loaded 6022_7.txt
# Loaded 6391_8.txt
# Loaded 10801_8.txt
# Loaded 2405_10.txt
# Loaded 8262_10.txt
# Loaded 9452_9.txt
# Loaded 3284_10.txt
# Loaded 11690_9.txt
# Loaded 9380_9.txt
# Loaded 11538_7.txt
# Loaded 4016_10.txt
# Loaded 1994_10.txt
# Loaded 1250_10.txt
# Loaded 6098_10.txt
# Loaded 2502_8.txt
# Loaded 3709_7.txt
# Loaded 3045_10.txt
# Loaded 2785_7.txt
# Loaded 5722_8.txt
# Loaded 6410_10.txt
# Loaded 9701_10.txt
# Loaded 7565_10.txt
# Loaded 5301_8.txt
# Loaded 770_10.txt
# Loaded 447_10.txt
# Loaded 2148_10.txt
# Loaded 6720_9.txt
# Loaded 7575_10.txt
# Loaded 6538_8.txt
# Loaded 2195_10.txt
# Loaded 10074_9.txt
# Loaded 985_7.txt
# Loaded 9923_7.txt
# Loaded 8268_7.txt
# Loaded 7544_7.txt
# Loaded 12148_10.txt
# Loaded 8312_10.txt
# Loaded 11699_10.txt
# Loaded 10705_7.txt
# Loaded 3956_10.txt
# Loaded 6342_10.txt
# Loaded 9377_7.txt
# Loaded 9150_8.txt
# Loaded 6328_10.txt
# Loaded 10140_8.txt
# Loaded 4175_8.txt
# Loaded 4834_8.txt
# Loaded 4647_8.txt
# Loaded 5738_10.txt
# Loaded 10034_8.txt
# Loaded 4818_9.txt
# Loaded 3508_8.txt
# Loaded 5869_10.txt
# Loaded 6287_10.txt
# Loaded 10272_10.txt
# Loaded 9852_7.txt
# Loaded 6070_8.txt
# Loaded 9335_10.txt
# Loaded 433_10.txt
# Loaded 11089_10.txt
# Loaded 9546_8.txt
# Loaded 2385_9.txt
# Loaded 7548_8.txt
# Loaded 1188_8.txt
# Loaded 2263_10.txt
# Loaded 6978_8.txt
# Loaded 8705_8.txt
# Loaded 9992_10.txt
# Loaded 880_10.txt
# Loaded 10319_7.txt
# Loaded 5196_9.txt
# Loaded 1778_10.txt
# Loaded 3477_10.txt
# Loaded 11607_10.txt
# Loaded 8152_10.txt
# Loaded 2602_10.txt
# Loaded 11702_10.txt
# Loaded 11003_10.txt
# Loaded 12397_8.txt
# Loaded 7362_10.txt
# Loaded 6205_8.txt
# Loaded 2078_9.txt
# Loaded 8270_10.txt
# Loaded 4984_8.txt
# Loaded 8342_7.txt
# Loaded 5133_10.txt
# Loaded 8421_10.txt
# Loaded 1090_8.txt
# Loaded 1138_10.txt
# Loaded 1785_9.txt
# Loaded 2128_8.txt
# Loaded 10914_8.txt
# Loaded 10463_10.txt
# Loaded 6596_8.txt
# Loaded 9763_8.txt
# Loaded 7413_9.txt
# Loaded 7021_10.txt
# Loaded 3611_10.txt
# Loaded 3352_9.txt
# Loaded 365_10.txt
# Loaded 6719_8.txt
# Loaded 1504_9.txt
# Loaded 5134_10.txt
# Loaded 10672_9.txt
# Loaded 1722_7.txt
# Loaded 1421_9.txt
# Loaded 9119_10.txt
# Loaded 8746_10.txt
# Loaded 2930_10.txt
# Loaded 10157_10.txt
# Loaded 12269_8.txt
# Loaded 9206_8.txt
# Loaded 6408_10.txt
# Loaded 11885_7.txt
# Loaded 2593_10.txt
# Loaded 9102_8.txt
# Loaded 7122_8.txt
# Loaded 5317_7.txt
# Loaded 6253_8.txt
# Loaded 1717_8.txt
# Loaded 5325_7.txt
# Loaded 9911_10.txt
# Loaded 2357_10.txt
# Loaded 11420_9.txt
# Loaded 9474_10.txt
# Loaded 9901_8.txt
# Loaded 6801_9.txt
# Loaded 455_10.txt
# Loaded 8056_8.txt
# Loaded 2741_10.txt
# Loaded 3307_8.txt
# Loaded 2413_10.txt
# Loaded 3355_10.txt
# Loaded 585_10.txt
# Loaded 9345_9.txt
# Loaded 10793_10.txt
# Loaded 1321_10.txt
# Loaded 6179_8.txt
# Loaded 3923_10.txt
# Loaded 3353_8.txt
# Loaded 2552_10.txt
# Loaded 4717_8.txt
# Loaded 10416_9.txt
# Loaded 11412_10.txt
# Loaded 6209_8.txt
# Loaded 897_10.txt
# Loaded 7829_7.txt
# Loaded 7691_9.txt
# Loaded 1099_10.txt
# Loaded 12398_8.txt
# Loaded 9092_7.txt
# Loaded 795_8.txt
# Loaded 5455_7.txt
# Loaded 5444_8.txt
# Loaded 6677_9.txt
# Loaded 10169_7.txt
# Loaded 7644_7.txt
# Loaded 5181_10.txt
# Loaded 9478_8.txt
# Loaded 6290_7.txt
# Loaded 6540_7.txt
# Loaded 166_7.txt
# Loaded 7938_7.txt
# Loaded 8106_7.txt
# Loaded 1019_10.txt
# Loaded 1285_9.txt
# Loaded 9877_8.txt
# Loaded 1398_7.txt
# Loaded 7529_10.txt
# Loaded 5452_8.txt
# Loaded 2397_9.txt
# Loaded 12273_10.txt
# Loaded 5794_10.txt
# Loaded 11222_8.txt
# Loaded 2695_10.txt
# Loaded 6883_9.txt
# Loaded 5939_7.txt
# Loaded 8034_10.txt
# Loaded 9203_9.txt
# Loaded 9329_8.txt
# Loaded 3331_8.txt
# Loaded 1500_9.txt
# Loaded 9768_10.txt
# Loaded 1631_8.txt
# Loaded 9398_9.txt
# Loaded 6240_10.txt
# Loaded 817_10.txt
# Loaded 5964_8.txt
# Loaded 8884_9.txt
# Loaded 4223_8.txt
# Loaded 11539_9.txt
# Loaded 275_10.txt
# Loaded 9016_10.txt
# Loaded 7343_10.txt
# Loaded 10251_10.txt
# Loaded 1900_8.txt
# Loaded 9689_9.txt
# Loaded 6612_8.txt
# Loaded 11100_10.txt
# Loaded 7660_10.txt
# Loaded 10475_8.txt
# Loaded 5321_10.txt
# Loaded 9100_7.txt
# Loaded 5336_8.txt
# Loaded 1178_10.txt
# Loaded 9223_9.txt
# Loaded 6957_7.txt
# Loaded 428_7.txt
# Loaded 3976_10.txt
# Loaded 4780_9.txt
# Loaded 6725_9.txt
# Loaded 8078_10.txt
# Loaded 10353_9.txt
# Loaded 2458_8.txt
# Loaded 7099_10.txt
# Loaded 963_8.txt
# Loaded 10614_7.txt
# Loaded 8137_10.txt
# Loaded 4316_10.txt
# Loaded 3648_8.txt
# Loaded 4181_9.txt
# Loaded 9000_10.txt
# Loaded 12152_9.txt
# Loaded 4005_10.txt
# Loaded 6864_7.txt
# Loaded 5361_10.txt
# Loaded 11068_9.txt
# Loaded 11575_10.txt
# Loaded 3497_10.txt
# Loaded 11818_10.txt
# Loaded 728_10.txt
# Loaded 4454_9.txt
# Loaded 11729_10.txt
# Loaded 7576_10.txt
# Loaded 12329_10.txt
# Loaded 6277_7.txt
# Loaded 3199_10.txt
# Loaded 9293_7.txt
# Loaded 7617_9.txt
# Loaded 6073_9.txt
# Loaded 7631_10.txt
# Loaded 4694_10.txt
# Loaded 6019_8.txt
# Loaded 4043_7.txt
# Loaded 12019_8.txt
# Loaded 12349_10.txt
# Loaded 11391_8.txt
# Loaded 1124_10.txt
# Loaded 2861_10.txt
# Loaded 3409_10.txt
# Loaded 4863_10.txt
# Loaded 2893_10.txt
# Loaded 1566_8.txt
# Loaded 11790_8.txt
# Loaded 5541_9.txt
# Loaded 3196_10.txt
# Loaded 12392_9.txt
# Loaded 595_9.txt
# Loaded 5712_8.txt
# Loaded 8747_7.txt
# Loaded 2396_7.txt
# Loaded 5940_7.txt
# Loaded 10005_7.txt
# Loaded 12193_10.txt
# Loaded 7838_8.txt
# Loaded 5780_10.txt
# Loaded 10893_8.txt
# Loaded 11730_10.txt
# Loaded 10012_8.txt
# Loaded 8254_8.txt
# Loaded 9113_8.txt
# Loaded 11362_9.txt
# Loaded 4141_10.txt
# Loaded 8419_9.txt
# Loaded 11233_10.txt
# Loaded 6698_10.txt
# Loaded 4460_9.txt
# Loaded 5231_10.txt
# Loaded 3496_8.txt
# Loaded 2902_9.txt
# Loaded 8976_7.txt
# Loaded 11627_8.txt
# Loaded 970_10.txt
# Loaded 12191_7.txt
# Loaded 110_10.txt
# Loaded 898_10.txt
# Loaded 1455_7.txt
# Loaded 6779_8.txt
# Loaded 12058_9.txt
# Loaded 1847_10.txt
# Loaded 7008_8.txt
# Loaded 6472_10.txt
# Loaded 3809_9.txt
# Loaded 9255_10.txt
# Loaded 8737_9.txt
# Loaded 9128_9.txt
# Loaded 6603_8.txt
# Loaded 9655_10.txt
# Loaded 8357_10.txt
# Loaded 3866_7.txt
# Loaded 9330_8.txt
# Loaded 12419_10.txt
# Loaded 274_7.txt
# Loaded 9521_10.txt
# Loaded 7407_10.txt
# Loaded 4410_10.txt
# Loaded 3212_7.txt
# Loaded 6326_10.txt
# Loaded 2806_10.txt
# Loaded 4208_10.txt
# Loaded 7663_7.txt
# Loaded 1189_9.txt
# Loaded 3141_10.txt
# Loaded 9876_8.txt
# Loaded 1597_8.txt
# Loaded 6556_9.txt
# Loaded 922_8.txt
# Loaded 3798_9.txt
# Loaded 6237_7.txt
# Loaded 3647_10.txt
# Loaded 10818_10.txt
# Loaded 6658_10.txt
# Loaded 5761_8.txt
# Loaded 9225_10.txt
# Loaded 11021_8.txt
# Loaded 5543_7.txt
# Loaded 6229_7.txt
# Loaded 9202_8.txt
# Loaded 3577_7.txt
# Loaded 5467_9.txt
# Loaded 583_8.txt
# Loaded 2149_10.txt
# Loaded 1443_8.txt
# Loaded 10329_8.txt
# Loaded 11666_10.txt
# Loaded 5354_10.txt
# Loaded 1363_10.txt
# Loaded 11226_7.txt
# Loaded 11832_7.txt
# Loaded 6875_10.txt
# Loaded 10162_9.txt
# Loaded 9287_9.txt
# Loaded 4842_10.txt
# Loaded 8877_9.txt
# Loaded 4274_10.txt
# Loaded 1214_10.txt
# Loaded 6490_10.txt
# Loaded 2713_8.txt
# Loaded 10076_9.txt
# Loaded 4000_10.txt
# Loaded 2055_10.txt
# Loaded 92_9.txt
# Loaded 3267_8.txt
# Loaded 5915_7.txt
# Loaded 10399_10.txt
# Loaded 3139_10.txt
# Loaded 1422_10.txt
# Loaded 5285_7.txt
# Loaded 10489_10.txt
# Loaded 8493_10.txt
# Loaded 6255_8.txt
# Loaded 2761_10.txt
# Loaded 736_10.txt
# Loaded 6189_10.txt
# Loaded 1757_8.txt
# Loaded 177_9.txt
# Loaded 10306_8.txt
# Loaded 10834_7.txt
# Loaded 8044_10.txt
# Loaded 8278_10.txt
# Loaded 4052_8.txt
# Loaded 4125_8.txt
# Loaded 3149_8.txt
# Loaded 3445_7.txt
# Loaded 10919_10.txt
# Loaded 3570_10.txt
# Loaded 5723_7.txt
# Loaded 4421_8.txt
# Loaded 1120_7.txt
# Loaded 9314_10.txt
# Loaded 3378_7.txt
# Loaded 10763_8.txt
# Loaded 5663_10.txt
# Loaded 6776_7.txt
# Loaded 3560_8.txt
# Loaded 3315_10.txt
# Loaded 8973_9.txt
# Loaded 1423_10.txt
# Loaded 3313_10.txt
# Loaded 1274_7.txt
# Loaded 5484_10.txt
# Loaded 8852_9.txt
# Loaded 2349_9.txt
# Loaded 5187_7.txt
# Loaded 5395_10.txt
# Loaded 6135_8.txt
# Loaded 10548_7.txt
# Loaded 10646_8.txt
# Loaded 5087_7.txt
# Loaded 9043_7.txt
# Loaded 3995_8.txt
# Loaded 397_9.txt
# Loaded 5221_7.txt
# Loaded 1182_8.txt
# Loaded 7821_8.txt
# Loaded 10783_10.txt
# Loaded 550_10.txt
# Loaded 2629_9.txt
# Loaded 228_7.txt
# Loaded 7633_8.txt
# Loaded 11172_10.txt
# Loaded 8363_8.txt
# Loaded 6146_7.txt
# Loaded 5141_9.txt
# Loaded 4276_10.txt
# Loaded 10468_9.txt
# Loaded 7721_7.txt
# Loaded 5542_9.txt
# Loaded 1086_7.txt
# Loaded 9767_7.txt
# Loaded 7538_7.txt
# Loaded 12306_9.txt
# Loaded 4157_8.txt
# Loaded 7186_7.txt
# Loaded 11867_8.txt
# Loaded 12231_10.txt
# Loaded 12182_8.txt
# Loaded 553_7.txt
# Loaded 12290_10.txt
# Loaded 1823_7.txt
# Loaded 2964_8.txt
# Loaded 162_8.txt
# Loaded 4097_8.txt
# Loaded 6075_10.txt
# Loaded 6544_10.txt
# Loaded 5890_8.txt
# Loaded 8260_9.txt
# Loaded 10707_8.txt
# Loaded 6663_10.txt
# Loaded 11389_7.txt
# Loaded 1007_10.txt
# Loaded 645_10.txt
# Loaded 10711_10.txt
# Loaded 10226_10.txt
# Loaded 5767_8.txt
# Loaded 6923_10.txt
# Loaded 3484_10.txt
# Loaded 4444_10.txt
# Loaded 11398_7.txt
# Loaded 3416_10.txt
# Loaded 4246_8.txt
# Loaded 3924_7.txt
# Loaded 7605_8.txt
# Loaded 205_8.txt
# Loaded 2311_10.txt
# Loaded 1957_7.txt
# Loaded 7326_10.txt
# Loaded 5489_10.txt
# Loaded 3129_10.txt
# Loaded 4197_8.txt
# Loaded 1881_7.txt
# Loaded 2511_10.txt
# Loaded 7510_8.txt
# Loaded 6967_7.txt
# Loaded 2437_10.txt
# Loaded 9628_8.txt
# Loaded 5324_10.txt
# Loaded 5788_8.txt
# Loaded 5709_10.txt
# Loaded 9429_9.txt
# Loaded 641_8.txt
# Loaded 4735_9.txt
# Loaded 6577_8.txt
# Loaded 6710_10.txt
# Loaded 9389_7.txt
# Loaded 400_10.txt
# Loaded 7720_8.txt
# Loaded 11755_7.txt
# Loaded 11531_10.txt
# Loaded 9996_9.txt
# Loaded 503_10.txt
# Loaded 10624_7.txt
# Loaded 11186_7.txt
# Loaded 5662_10.txt
# Loaded 9512_8.txt
# Loaded 10736_10.txt
# Loaded 12302_7.txt
# Loaded 8055_8.txt
# Loaded 11473_10.txt
# Loaded 1343_9.txt
# Loaded 12265_10.txt
# Loaded 1026_9.txt
# Loaded 3738_8.txt
# Loaded 5989_7.txt
# Loaded 459_10.txt
# Loaded 8025_9.txt
# Loaded 6822_7.txt
# Loaded 10265_9.txt
# Loaded 11788_8.txt
# Loaded 1367_10.txt
# Loaded 8047_9.txt
# Loaded 11564_9.txt
# Loaded 4960_9.txt
# Loaded 5984_10.txt
# Loaded 2373_7.txt
# Loaded 5138_10.txt
# Loaded 5020_10.txt
# Loaded 10660_10.txt
# Loaded 2243_7.txt
# Loaded 12292_10.txt
# Loaded 8972_10.txt
# Loaded 8378_10.txt
# Loaded 6074_7.txt
# Loaded 1673_8.txt
# Loaded 1978_9.txt
# Loaded 3479_9.txt
# Loaded 3702_9.txt
# Loaded 3898_10.txt
# Loaded 5350_9.txt
# Loaded 8902_7.txt
# Loaded 34_8.txt
# Loaded 10961_9.txt
# Loaded 11230_10.txt
# Loaded 114_10.txt
# Loaded 6273_9.txt
# Loaded 8933_7.txt
# Loaded 2012_8.txt
# Loaded 6121_10.txt
# Loaded 9085_8.txt
# Loaded 6066_10.txt
# Loaded 5471_8.txt
# Loaded 7248_9.txt
# Loaded 8868_10.txt
# Loaded 1451_8.txt
# Loaded 11837_7.txt
# Loaded 4719_10.txt
# Loaded 2751_10.txt
# Loaded 754_9.txt
# Loaded 6473_8.txt
# Loaded 8689_7.txt
# Loaded 4883_10.txt
# Loaded 4672_10.txt
# Loaded 6385_10.txt
# Loaded 308_8.txt
# Loaded 1144_8.txt
# Loaded 2100_7.txt
# Loaded 72_7.txt
# Loaded 11197_8.txt
# Loaded 3158_8.txt
# Loaded 3664_10.txt
# Loaded 7056_7.txt
# Loaded 2869_10.txt
# Loaded 11794_7.txt
# Loaded 5124_10.txt
# Loaded 8722_9.txt
# Loaded 5982_9.txt
# Loaded 11006_7.txt
# Loaded 260_7.txt
# Loaded 8383_7.txt
# Loaded 9177_10.txt
# Loaded 1330_9.txt
# Loaded 8996_8.txt
# Loaded 10234_10.txt
# Loaded 3557_9.txt
# Loaded 5507_7.txt
# Loaded 6258_8.txt
# Loaded 4936_8.txt
# Loaded 5158_10.txt
# Loaded 870_10.txt
# Loaded 1833_10.txt
# Loaded 6125_9.txt
# Loaded 4467_7.txt
# Loaded 1176_10.txt
# Loaded 2429_8.txt
# Loaded 11527_7.txt
# Loaded 11083_10.txt
# Loaded 1190_7.txt
# Loaded 714_10.txt
# Loaded 10196_10.txt
# Loaded 8395_8.txt
# Loaded 7050_7.txt
# Loaded 2052_10.txt
# Loaded 10583_10.txt
# Loaded 3227_7.txt
# Loaded 6827_10.txt
# Loaded 1219_10.txt
# Loaded 12251_9.txt
# Loaded 10418_9.txt
# Loaded 4473_8.txt
# Loaded 530_10.txt
# Loaded 4153_10.txt
# Loaded 8738_8.txt
# Loaded 2853_8.txt
# Loaded 10190_7.txt
# Loaded 5360_10.txt
# Loaded 2931_10.txt
# Loaded 12486_7.txt
# Loaded 11546_9.txt
# Loaded 3134_8.txt
# Loaded 10815_10.txt
# Loaded 11232_10.txt
# Loaded 3896_7.txt
# Loaded 7490_8.txt
# Loaded 9457_9.txt
# Loaded 6555_8.txt
# Loaded 73_7.txt
# Loaded 3920_9.txt
# Loaded 4257_10.txt
# Loaded 11048_7.txt
# Loaded 9869_10.txt
# Loaded 11304_7.txt
# Loaded 3887_10.txt
# Loaded 7172_10.txt
# Loaded 11383_7.txt
# Loaded 4299_8.txt
# Loaded 10023_9.txt
# Loaded 8553_7.txt
# Loaded 5530_8.txt
# Loaded 12044_7.txt
# Loaded 4955_9.txt
# Loaded 6272_7.txt
# Loaded 2262_10.txt
# Loaded 12316_10.txt
# Loaded 3430_10.txt
# Loaded 7782_7.txt
# Loaded 6194_8.txt
# Loaded 11797_8.txt
# Loaded 4932_8.txt
# Loaded 5377_7.txt
# Loaded 2017_10.txt
# Loaded 4359_10.txt
# Loaded 5727_9.txt
# Loaded 2410_9.txt
# Loaded 1277_10.txt
# Loaded 11410_7.txt
# Loaded 5412_9.txt
# Loaded 676_8.txt
# Loaded 432_8.txt
# Loaded 11284_8.txt
# Loaded 4086_7.txt
# Loaded 7651_8.txt
# Loaded 385_10.txt
# Loaded 3321_7.txt
# Loaded 6711_10.txt
# Loaded 10062_10.txt
# Loaded 1341_10.txt
# Loaded 4090_8.txt
# Loaded 3017_7.txt
# Loaded 1703_8.txt
# Loaded 6976_9.txt
# Loaded 5733_7.txt
# Loaded 2020_7.txt
# Loaded 2280_7.txt
# Loaded 1472_8.txt
# Loaded 4243_8.txt
# Loaded 4418_10.txt
# Loaded 7282_9.txt
# Loaded 2890_7.txt
# Loaded 7979_9.txt
# Loaded 5038_10.txt
# Loaded 12059_9.txt
# Loaded 678_8.txt
# Loaded 12074_10.txt
# Loaded 7101_10.txt
# Loaded 9415_8.txt
# Loaded 4085_10.txt
# Loaded 5750_8.txt
# Loaded 10568_10.txt
# Loaded 6242_8.txt
# Loaded 8783_9.txt
# Loaded 5493_10.txt
# Loaded 12482_8.txt
# Loaded 1644_10.txt
# Loaded 2435_8.txt
# Loaded 10661_9.txt
# Loaded 6090_7.txt
# Loaded 2094_10.txt
# Loaded 3682_8.txt
# Loaded 5436_7.txt
# Loaded 3260_8.txt
# Loaded 8315_10.txt
# Loaded 3316_10.txt
# Loaded 8975_10.txt
# Loaded 10984_10.txt
# Loaded 4084_7.txt
# Loaded 2174_8.txt
# Loaded 4644_10.txt
# Loaded 3945_10.txt
# Loaded 4528_8.txt
# Loaded 8033_7.txt
# Loaded 2049_7.txt
# Loaded 3831_10.txt
# Loaded 7688_10.txt
# Loaded 1527_7.txt
# Loaded 2079_10.txt
# Loaded 8733_10.txt
# Loaded 11880_10.txt
# Loaded 4729_10.txt
# Loaded 11617_9.txt
# Loaded 1217_10.txt
# Loaded 7449_10.txt
# Loaded 8417_8.txt
# Loaded 4867_9.txt
# Loaded 8856_8.txt
# Loaded 8529_9.txt
# Loaded 11996_10.txt
# Loaded 8842_9.txt
# Loaded 158_10.txt
# Loaded 10504_9.txt
# Loaded 1257_10.txt
# Loaded 7061_7.txt
# Loaded 387_8.txt
# Loaded 9947_10.txt
# Loaded 1857_10.txt
# Loaded 10151_8.txt
# Loaded 607_10.txt
# Loaded 771_7.txt
# Loaded 12490_8.txt
# Loaded 336_10.txt
# Loaded 12083_8.txt
# Loaded 3852_8.txt
# Loaded 4966_10.txt
# Loaded 3515_7.txt
# Loaded 11322_9.txt
# Loaded 5496_9.txt
# Loaded 2003_8.txt
# Loaded 7178_10.txt
# Loaded 5832_9.txt
# Loaded 6360_7.txt
# Loaded 9888_10.txt
# Loaded 8611_8.txt
# Loaded 7402_8.txt
# Loaded 1114_8.txt
# Loaded 11873_8.txt
# Loaded 144_8.txt
# Loaded 7290_10.txt
# Loaded 11653_10.txt
# Loaded 6508_7.txt
# Loaded 2710_7.txt
# Loaded 6986_8.txt
# Loaded 6482_10.txt
# Loaded 1752_8.txt
# Loaded 11393_7.txt
# Loaded 10702_10.txt
# Loaded 11294_10.txt
# Loaded 4251_9.txt
# Loaded 3392_7.txt
# Loaded 2760_8.txt
# Loaded 5602_10.txt
# Loaded 10291_7.txt
# Loaded 2322_10.txt
# Loaded 6092_8.txt
# Loaded 4508_7.txt
# Loaded 4098_10.txt
# Loaded 689_10.txt
# Loaded 545_10.txt
# Loaded 12315_9.txt
# Loaded 4497_7.txt
# Loaded 3502_9.txt
# Loaded 3906_10.txt
# Loaded 9472_8.txt
# Loaded 2601_10.txt
# Loaded 7661_10.txt
# Loaded 10511_7.txt
# Loaded 10722_10.txt
# Loaded 3782_8.txt
# Loaded 36_10.txt
# Loaded 735_8.txt
# Loaded 5424_10.txt
# Loaded 11087_8.txt
# Loaded 4502_7.txt
# Loaded 4641_9.txt
# Loaded 1623_10.txt
# Loaded 724_10.txt
# Loaded 11798_10.txt
# Loaded 5001_7.txt
# Loaded 9456_8.txt
# Loaded 6621_8.txt
# Loaded 4549_7.txt
# Loaded 2617_10.txt
# Loaded 6051_9.txt
# Loaded 2448_8.txt
# Loaded 9048_8.txt
# Loaded 9860_7.txt
# Loaded 4038_10.txt
# Loaded 12081_8.txt
# Loaded 6411_10.txt
# Loaded 2088_8.txt
# Loaded 5514_9.txt
# Loaded 10854_10.txt
# Loaded 10476_9.txt
# Loaded 3038_8.txt
# Loaded 4716_9.txt
# Loaded 11987_7.txt
# Loaded 621_10.txt
# Loaded 7162_10.txt
# Loaded 6476_10.txt
# Loaded 5327_10.txt
# Loaded 3553_8.txt
# Loaded 4504_9.txt
# Loaded 362_10.txt
# Loaded 864_9.txt
# Loaded 10321_10.txt
# Loaded 6171_8.txt
# Loaded 10435_7.txt
# Loaded 6267_10.txt
# Loaded 6545_10.txt
# Loaded 10339_7.txt
# Loaded 10580_8.txt
# Loaded 4330_10.txt
# Loaded 10560_9.txt
# Loaded 12499_7.txt
# Loaded 1155_10.txt
# Loaded 778_10.txt
# Loaded 11776_9.txt
# Loaded 9840_10.txt
# Loaded 1267_7.txt
# Loaded 11046_8.txt
# Loaded 12060_9.txt
# Loaded 5025_10.txt
# Loaded 8667_7.txt
# Loaded 12332_8.txt
# Loaded 6505_10.txt
# Loaded 3816_7.txt
# Loaded 10343_7.txt
# Loaded 7809_10.txt
# Loaded 6282_7.txt
# Loaded 2326_8.txt
# Loaded 328_10.txt
# Loaded 6999_7.txt
# Loaded 5023_10.txt
# Loaded 2184_7.txt
# Loaded 6642_10.txt
# Loaded 7123_10.txt
# Loaded 4214_10.txt
# Loaded 9370_7.txt
# Loaded 8310_10.txt
# Loaded 9428_10.txt
# Loaded 10103_8.txt
# Loaded 2377_10.txt
# Loaded 11619_9.txt
# Loaded 10635_8.txt
# Loaded 316_10.txt
# Loaded 9693_8.txt
# Loaded 1169_8.txt
# Loaded 12096_8.txt
# Loaded 9868_9.txt
# Loaded 5209_8.txt
# Loaded 3633_10.txt
# Loaded 4996_9.txt
# Loaded 4104_9.txt
# Loaded 6546_10.txt
# Loaded 11655_10.txt
# Loaded 2681_7.txt
# Loaded 2578_10.txt
# Loaded 8505_8.txt
# Loaded 11869_10.txt
# Loaded 4408_8.txt
# Loaded 8279_10.txt
# Loaded 11604_8.txt
# Loaded 10761_10.txt
# Loaded 3380_7.txt
# Loaded 9290_9.txt
# Loaded 6373_10.txt
# Loaded 8697_7.txt
# Loaded 11855_7.txt
# Loaded 11612_10.txt
# Loaded 6151_7.txt
# Loaded 10622_10.txt
# Loaded 1439_7.txt
# Loaded 11597_10.txt
# Loaded 3791_10.txt
# Loaded 6280_7.txt
# Loaded 5459_8.txt
# Loaded 1662_7.txt
# Loaded 11039_8.txt
# Loaded 12225_7.txt
# Loaded 30_7.txt
# Loaded 8196_8.txt
# Loaded 6676_9.txt
# Loaded 6693_10.txt
# Loaded 6440_8.txt
# Loaded 9622_10.txt
# Loaded 7724_10.txt
# Loaded 2348_10.txt
# Loaded 648_7.txt
# Loaded 5311_7.txt
# Loaded 1588_8.txt
# Loaded 4187_7.txt
# Loaded 3530_7.txt
# Loaded 6099_8.txt
# Loaded 4572_10.txt
# Loaded 6879_10.txt
# Loaded 8803_10.txt
# Loaded 5059_7.txt
# Loaded 1521_8.txt
# Loaded 3510_7.txt
# Loaded 4298_10.txt
# Loaded 8928_10.txt
# Loaded 12052_9.txt
# Loaded 11825_8.txt
# Loaded 55_9.txt
# Loaded 2622_8.txt
# Loaded 1110_9.txt
# Loaded 5645_10.txt
# Loaded 4180_10.txt
# Loaded 3245_10.txt
# Loaded 11804_10.txt
# Loaded 8861_9.txt
# Loaded 11900_8.txt
# Loaded 3428_9.txt
# Loaded 4679_10.txt
# Loaded 543_10.txt
# Loaded 11972_10.txt
# Loaded 4168_7.txt
# Loaded 331_10.txt
# Loaded 3630_7.txt
# Loaded 4522_9.txt
# Loaded 2393_8.txt
# Loaded 8067_8.txt
# Loaded 9259_10.txt
# Loaded 5972_8.txt
# Loaded 9350_10.txt
# Loaded 169_8.txt
# Loaded 7989_10.txt
# Loaded 7077_10.txt
# Loaded 997_7.txt
# Loaded 76_7.txt
# Loaded 10350_10.txt
# Loaded 2586_10.txt
# Loaded 7885_9.txt
# Loaded 6975_8.txt
# Loaded 6087_9.txt
# Loaded 11129_10.txt
# Loaded 6340_10.txt
# Loaded 6624_9.txt
# Loaded 8519_10.txt
# Loaded 3053_8.txt
# Loaded 8748_8.txt
# Loaded 7445_7.txt
# Loaded 11480_10.txt
# Loaded 11839_9.txt
# Loaded 5264_7.txt
# Loaded 2734_9.txt
# Loaded 2364_10.txt
# Loaded 9302_10.txt
# Loaded 3475_9.txt
# Loaded 10231_10.txt
# Loaded 4598_9.txt
# Loaded 7539_10.txt
# Loaded 6792_10.txt
# Loaded 5227_10.txt
# Loaded 8189_10.txt
# Loaded 11823_9.txt
# Loaded 3992_8.txt
# Loaded 2294_8.txt
# Loaded 4668_10.txt
# Loaded 4119_8.txt
# Loaded 9096_10.txt
# Loaded 4564_10.txt
# Loaded 2887_9.txt
# Loaded 7477_9.txt
# Loaded 2809_8.txt
# Loaded 4768_10.txt
# Loaded 11079_8.txt
# Loaded 9919_9.txt
# Loaded 3532_8.txt
# Loaded 7180_9.txt
# Loaded 8974_10.txt
# Loaded 6840_10.txt
# Loaded 12308_10.txt
# Loaded 5596_10.txt
# Loaded 5032_10.txt
# Loaded 5882_9.txt
# Loaded 8843_7.txt
# Loaded 3362_8.txt
# Loaded 2733_10.txt
# Loaded 10596_8.txt
# Loaded 12278_10.txt
# Loaded 5362_8.txt
# Loaded 11496_10.txt
# Loaded 3652_10.txt
# Loaded 649_10.txt
# Loaded 4339_10.txt
# Loaded 4498_8.txt
# Loaded 4875_7.txt
# Loaded 12107_10.txt
# Loaded 2618_7.txt
# Loaded 4651_7.txt
# Loaded 5994_8.txt
# Loaded 4816_8.txt
# Loaded 2217_7.txt
# Loaded 3671_7.txt
# Loaded 5559_7.txt
# Loaded 11608_10.txt
# Loaded 4106_7.txt
# Loaded 12483_9.txt
# Loaded 10940_10.txt
# Loaded 271_10.txt
# Loaded 12330_7.txt
# Loaded 6067_10.txt
# Loaded 6543_9.txt
# Loaded 9295_10.txt
# Loaded 7226_8.txt
# Loaded 906_10.txt
# Loaded 9131_9.txt
# Loaded 6247_10.txt
# Loaded 4700_9.txt
# Loaded 9381_8.txt
# Loaded 2528_10.txt
# Loaded 5569_7.txt
# Loaded 1913_10.txt
# Loaded 11122_10.txt
# Loaded 3400_8.txt
# Loaded 4949_8.txt
# Loaded 6177_7.txt
# Loaded 7341_8.txt
# Loaded 8989_9.txt
# Loaded 5985_10.txt
# Loaded 8828_10.txt
# Loaded 10997_10.txt
# Loaded 3114_9.txt
# Loaded 2381_9.txt
# Loaded 1233_7.txt
# Loaded 9927_9.txt
# Loaded 663_8.txt
# Loaded 7501_8.txt
# Loaded 8251_10.txt
# Loaded 52_10.txt
# Loaded 7352_10.txt
# Loaded 9967_10.txt
# Loaded 829_7.txt
# Loaded 2358_9.txt
# Loaded 10670_10.txt
# Loaded 11469_10.txt
# Loaded 3401_8.txt
# Loaded 7784_7.txt
# Loaded 12293_10.txt
# Loaded 7826_8.txt
# Loaded 3471_8.txt
# Loaded 2038_7.txt
# Loaded 4132_7.txt
# Loaded 4259_9.txt
# Loaded 11922_10.txt
# Loaded 6865_7.txt
# Loaded 4184_8.txt
# Loaded 6466_10.txt
# Loaded 6260_10.txt
# Loaded 9957_7.txt
# Loaded 9358_8.txt
# Loaded 4625_10.txt
# Loaded 8001_10.txt
# Loaded 11107_10.txt
# Loaded 2069_9.txt
# Loaded 11639_10.txt
# Loaded 12277_10.txt
# Loaded 12084_8.txt
# Loaded 6943_9.txt
# Loaded 546_10.txt
# Loaded 11074_7.txt
# Loaded 2220_9.txt
# Loaded 8939_9.txt
# Loaded 7908_9.txt
# Loaded 7889_10.txt
# Loaded 3297_10.txt
# Loaded 9117_10.txt
# Loaded 11162_10.txt
# Loaded 2132_9.txt
# Loaded 11429_7.txt
# Loaded 10488_10.txt
# Loaded 8786_8.txt
# Loaded 10267_8.txt
# Loaded 5665_9.txt
# Loaded 8187_9.txt
# Loaded 11117_10.txt
# Loaded 3154_10.txt
# Loaded 4105_10.txt
# Loaded 7163_10.txt
# Loaded 7500_8.txt
# Loaded 11239_8.txt
# Loaded 8401_10.txt
# Loaded 8769_7.txt
# Loaded 8557_7.txt
# Loaded 6532_8.txt
# Loaded 6114_7.txt
# Loaded 3249_9.txt
# Loaded 11574_10.txt
# Loaded 4282_10.txt
# Loaded 9406_8.txt
# Loaded 8061_10.txt
# Loaded 1299_10.txt
# Loaded 4303_10.txt
# Loaded 3909_10.txt
# Loaded 7902_10.txt
# Loaded 7828_10.txt
# Loaded 10985_9.txt
# Loaded 3543_10.txt
# Loaded 4116_9.txt
# Loaded 11296_8.txt
# Loaded 9773_7.txt
# Loaded 5576_9.txt
# Loaded 12055_10.txt
# Loaded 8038_7.txt
# Loaded 9533_9.txt
# Loaded 6335_10.txt
# Loaded 2123_10.txt
# Loaded 10415_7.txt
# Loaded 9915_8.txt
# Loaded 9857_7.txt
# Loaded 2359_10.txt
# Loaded 1601_8.txt
# Loaded 7317_10.txt
# Loaded 5429_10.txt
# Loaded 1425_7.txt
# Loaded 11281_8.txt
# Loaded 1376_7.txt
# Loaded 4632_10.txt
# Loaded 6350_8.txt
# Loaded 4590_10.txt
# Loaded 5953_9.txt
# Loaded 8608_9.txt
# Loaded 11478_8.txt
# Loaded 4535_7.txt
# Loaded 5716_8.txt
# Loaded 8770_7.txt
# Loaded 181_10.txt
# Loaded 6213_7.txt
# Loaded 11438_10.txt
# Loaded 3146_10.txt
# Loaded 11741_10.txt
# Loaded 729_10.txt
# Loaded 4521_10.txt
# Loaded 5486_10.txt
# Loaded 142_8.txt
# Loaded 4796_8.txt
# Loaded 1874_10.txt
# Loaded 8425_9.txt
# Loaded 1354_9.txt
# Loaded 4374_10.txt
# Loaded 6187_9.txt
# Loaded 5189_10.txt
# Loaded 8821_9.txt
# Loaded 2379_8.txt
# Loaded 899_7.txt
# Loaded 10125_8.txt
# Loaded 12300_10.txt
# Loaded 4486_7.txt
# Loaded 4095_8.txt
# Loaded 6436_10.txt
# Loaded 2045_9.txt
# Loaded 1078_8.txt
# Loaded 1256_8.txt
# Loaded 10288_10.txt
# Loaded 5401_9.txt
# Loaded 8516_9.txt
# Loaded 5408_7.txt
# Loaded 712_9.txt
# Loaded 10886_10.txt
# Loaded 2443_9.txt
# Loaded 1057_9.txt
# Loaded 7652_8.txt
# Loaded 8289_8.txt
# Loaded 999_10.txt
# Loaded 1419_7.txt
# Loaded 3054_7.txt
# Loaded 5757_8.txt
# Loaded 8257_9.txt
# Loaded 5456_10.txt
# Loaded 8616_8.txt
# Loaded 6597_9.txt
# Loaded 9365_9.txt
# Loaded 10791_9.txt
# Loaded 995_9.txt
# Loaded 7866_10.txt
# Loaded 2102_10.txt
# Loaded 5497_9.txt
# Loaded 669_7.txt
# Loaded 5182_8.txt
# Loaded 8906_8.txt
# Loaded 6639_10.txt
# Loaded 11351_9.txt
# Loaded 4382_8.txt
# Loaded 12439_8.txt
# Loaded 4329_7.txt
# Loaded 11259_10.txt
# Loaded 6016_10.txt
# Loaded 923_9.txt
# Loaded 3615_9.txt
# Loaded 3187_7.txt
# Loaded 3298_10.txt
# Loaded 9667_9.txt
# Loaded 201_10.txt
# Loaded 8381_8.txt
# Loaded 2550_9.txt
# Loaded 8427_7.txt
# Loaded 11847_9.txt
# Loaded 3835_9.txt
# Loaded 2018_9.txt
# Loaded 5758_10.txt
# Loaded 8304_8.txt
# Loaded 731_9.txt
# Loaded 7271_7.txt
# Loaded 5414_10.txt
# Loaded 4520_7.txt
# Loaded 9564_10.txt
# Loaded 11115_10.txt
# Loaded 5720_10.txt
# Loaded 7334_7.txt
# Loaded 1580_7.txt
# Loaded 11271_7.txt
# Loaded 293_7.txt
# Loaded 3451_8.txt
# Loaded 2940_10.txt
# Loaded 10926_9.txt
# Loaded 1074_10.txt
# Loaded 525_10.txt
# Loaded 6141_9.txt
# Loaded 475_10.txt
# Loaded 2325_8.txt
# Loaded 6474_8.txt
# Loaded 1411_7.txt
# Loaded 1311_10.txt
# Loaded 6514_10.txt
# Loaded 5186_10.txt
# Loaded 6139_10.txt
# Loaded 3465_9.txt
# Loaded 6968_7.txt
# Loaded 6646_10.txt
# Loaded 8527_8.txt
# Loaded 9925_7.txt
# Loaded 5188_8.txt
# Loaded 6413_7.txt
# Loaded 11114_10.txt
# Loaded 8256_9.txt
# Loaded 6788_9.txt
# Loaded 4185_8.txt
# Loaded 5688_8.txt
# Loaded 8574_9.txt
# Loaded 11732_7.txt
# Loaded 5166_10.txt
# Loaded 8830_8.txt
# Loaded 11097_9.txt
# Loaded 1345_9.txt
# Loaded 9039_10.txt
# Loaded 11920_9.txt
# Loaded 5253_10.txt
# Loaded 1967_8.txt
# Loaded 7903_10.txt
# Loaded 4890_10.txt
# Loaded 12226_8.txt
# Loaded 8649_9.txt
# Loaded 3116_10.txt
# Loaded 7626_9.txt
# Loaded 4217_9.txt
# Loaded 7388_10.txt
# Loaded 10171_7.txt
# Loaded 3728_10.txt
# Loaded 2345_9.txt
# Loaded 8567_10.txt
# Loaded 11278_8.txt
# Loaded 11285_7.txt
# Loaded 5256_10.txt
# Loaded 7917_8.txt
# Loaded 8507_10.txt
# Loaded 10694_7.txt
# Loaded 8546_10.txt
# Loaded 9082_10.txt
# Loaded 4964_10.txt
# Loaded 2313_10.txt
# Loaded 3826_10.txt
# Loaded 5936_10.txt
# Loaded 4143_9.txt
# Loaded 10880_8.txt
# Loaded 9083_8.txt
# Loaded 9968_9.txt
# Loaded 6542_8.txt
# Loaded 11846_10.txt
# Loaded 12153_10.txt
# Loaded 11413_10.txt
# Loaded 11524_7.txt
# Loaded 8127_8.txt
# Loaded 10065_9.txt
# Loaded 10718_10.txt
# Loaded 6651_10.txt
# Loaded 4081_10.txt
# Loaded 7049_7.txt
# Loaded 9216_10.txt
# Loaded 7126_10.txt
# Loaded 8258_9.txt
# Loaded 10367_8.txt
# Loaded 7411_10.txt
# Loaded 5145_10.txt
# Loaded 6439_10.txt
# Loaded 5242_7.txt
# Loaded 8772_8.txt
# Loaded 8084_7.txt
# Loaded 11767_8.txt
# Loaded 7936_7.txt
# Loaded 4489_9.txt
# Loaded 4149_10.txt
# Loaded 7470_10.txt
# Loaded 3265_10.txt
# Loaded 8870_8.txt
# Loaded 178_7.txt
# Loaded 235_10.txt
# Loaded 7037_10.txt
# Loaded 6517_10.txt
# Loaded 2668_9.txt
# Loaded 831_9.txt
# Loaded 3427_8.txt
# Loaded 12362_8.txt
# Loaded 8247_9.txt
# Loaded 1051_9.txt
# Loaded 1960_7.txt
# Loaded 3746_10.txt
# Loaded 7580_7.txt
# Loaded 1773_9.txt
# Loaded 8523_9.txt
# Loaded 10261_8.txt
# Loaded 3348_7.txt
# Loaded 4999_9.txt
# Loaded 386_7.txt
# Loaded 9635_7.txt
# Loaded 9506_8.txt
# Loaded 7219_7.txt
# Loaded 10361_7.txt
# Loaded 9332_10.txt
# Loaded 693_10.txt
# Loaded 11534_7.txt
# Loaded 6669_10.txt
# Loaded 7300_8.txt
# Loaded 4066_10.txt
# Loaded 11766_8.txt
# Loaded 944_10.txt
# Loaded 11836_10.txt
# Loaded 2999_7.txt
# Loaded 1870_10.txt
# Loaded 1615_8.txt
# Loaded 5725_9.txt
# Loaded 9518_10.txt
# Loaded 5014_9.txt
# Loaded 7528_10.txt
# Loaded 8212_7.txt
# Loaded 962_8.txt
# Loaded 4854_7.txt
# Loaded 2470_10.txt
# Loaded 10806_9.txt
# Loaded 11103_10.txt
# Loaded 6401_8.txt
# Loaded 5385_7.txt
# Loaded 7816_9.txt
# Loaded 1763_9.txt
# Loaded 5566_9.txt
# Loaded 3188_8.txt
# Loaded 4977_7.txt
# Loaded 4176_10.txt
# Loaded 1522_8.txt
# Loaded 804_10.txt
# Loaded 2989_10.txt
# Loaded 2724_9.txt
# Loaded 6614_9.txt
# Loaded 11385_8.txt
# Loaded 9599_9.txt
# Loaded 9871_7.txt
# Loaded 4267_8.txt
# Loaded 10534_7.txt
# Loaded 6951_10.txt
# Loaded 5958_9.txt
# Loaded 9338_8.txt
# Loaded 6397_8.txt
# Loaded 9401_10.txt
# Loaded 5990_7.txt
# Loaded 11701_9.txt
# Loaded 6708_10.txt
# Loaded 3423_7.txt
# Loaded 12314_10.txt
# Loaded 244_10.txt
# Loaded 3608_9.txt
# Loaded 10114_10.txt
# Loaded 12311_9.txt
# Loaded 8944_8.txt
# Loaded 6661_7.txt
# Loaded 11425_8.txt
# Loaded 1073_9.txt
# Loaded 8875_9.txt
# Loaded 4060_10.txt
# Loaded 2991_7.txt
# Loaded 3856_10.txt
# Loaded 8451_10.txt
# Loaded 9710_10.txt
# Loaded 6210_10.txt
# Loaded 4578_9.txt
# Loaded 2215_8.txt
# Loaded 7340_8.txt
# Loaded 4586_7.txt
# Loaded 10868_8.txt
# Loaded 476_7.txt
# Loaded 6885_9.txt
# Loaded 7231_8.txt
# Loaded 3176_9.txt
# Loaded 10316_8.txt
# Loaded 8600_8.txt
# Loaded 2223_8.txt
# Loaded 10883_7.txt
# Loaded 5027_10.txt
# Loaded 2065_7.txt
# Loaded 677_8.txt
# Loaded 7846_10.txt
# Loaded 4459_7.txt
# Loaded 1781_10.txt
# Loaded 699_8.txt
# Loaded 4985_10.txt
# Loaded 3008_7.txt
# Loaded 2925_10.txt
# Loaded 1296_10.txt
# Loaded 10200_10.txt
# Loaded 2509_9.txt
# Loaded 191_9.txt
# Loaded 1815_10.txt
# Loaded 8142_10.txt
# Loaded 9159_10.txt
# Loaded 3241_8.txt
# Loaded 8346_9.txt
# Loaded 7939_8.txt
# Loaded 10876_7.txt
# Loaded 7790_9.txt
# Loaded 11993_9.txt
# Loaded 35_8.txt
# Loaded 7320_10.txt
# Loaded 5278_7.txt
# Loaded 4934_8.txt
# Loaded 7423_9.txt
# Loaded 4910_8.txt
# Loaded 11229_10.txt
# Loaded 4981_10.txt
# Loaded 4487_9.txt
# Loaded 1844_8.txt
# Loaded 8927_8.txt
# Loaded 1385_8.txt
# Loaded 1154_10.txt
# Loaded 3607_8.txt
# Loaded 264_7.txt
# Loaded 10453_10.txt
# Loaded 1564_10.txt
# Loaded 344_8.txt
# Loaded 8900_10.txt
# Loaded 8716_10.txt
# Loaded 11205_10.txt
# Loaded 7327_10.txt
# Loaded 3303_10.txt
# Loaded 7284_8.txt
# Loaded 2266_8.txt
# Loaded 4933_8.txt
# Loaded 7309_9.txt
# Loaded 9403_8.txt
# Loaded 6882_9.txt
# Loaded 1117_10.txt
# Loaded 1808_7.txt
# Loaded 6441_9.txt
# Loaded 2239_7.txt
# Loaded 2064_8.txt
# Loaded 5279_8.txt
# Loaded 3987_7.txt
# Loaded 9492_7.txt
# Loaded 10709_10.txt
# Loaded 658_10.txt
# Loaded 10765_10.txt
# Loaded 2859_10.txt
# Loaded 4333_10.txt
# Loaded 8364_10.txt
# Loaded 11176_9.txt
# Loaded 5126_7.txt
# Loaded 1023_10.txt
# Loaded 1452_8.txt
# Loaded 44_8.txt
# Loaded 6224_7.txt
# Loaded 10759_9.txt
# Loaded 12357_7.txt
# Loaded 53_10.txt
# Loaded 6500_10.txt
# Loaded 10447_10.txt
# Loaded 9576_9.txt
# Loaded 6181_9.txt
# Loaded 11854_7.txt
# Loaded 903_8.txt
# Loaded 12210_9.txt
# Loaded 490_9.txt
# Loaded 3013_8.txt
# Loaded 5479_10.txt
# Loaded 5021_10.txt
# Loaded 9818_7.txt
# Loaded 4814_10.txt
# Loaded 1942_10.txt
# Loaded 894_9.txt
# Loaded 2382_7.txt
# Loaded 11018_10.txt
# Loaded 7739_10.txt
# Loaded 5807_8.txt
# Loaded 5494_10.txt
# Loaded 9709_10.txt
# Loaded 5400_10.txt
# Loaded 9049_8.txt
# Loaded 2845_8.txt
# Loaded 312_10.txt
# Loaded 4324_7.txt
# Loaded 11504_8.txt
# Loaded 434_8.txt
# Loaded 11130_9.txt
# Loaded 10864_8.txt
# Loaded 5445_10.txt
# Loaded 131_10.txt
# Loaded 4804_7.txt
# Loaded 10464_7.txt
# Loaded 8936_8.txt
# Loaded 4556_8.txt
# Loaded 12067_9.txt
# Loaded 12453_7.txt
# Loaded 2972_7.txt
# Loaded 3235_9.txt
# Loaded 720_7.txt
# Loaded 7555_7.txt
# Loaded 6703_8.txt
# Loaded 126_10.txt
# Loaded 8017_9.txt
# Loaded 4160_9.txt
# Loaded 1358_10.txt
# Loaded 10014_8.txt
# Loaded 2342_8.txt
# Loaded 9823_7.txt
# Loaded 1495_9.txt
# Loaded 8020_8.txt
# Loaded 5435_10.txt
# Loaded 11555_10.txt
# Loaded 3748_10.txt
# Loaded 2752_7.txt
# Loaded 8862_8.txt
# Loaded 861_7.txt
# Loaded 1789_7.txt
# Loaded 694_9.txt
# Loaded 2169_7.txt
# Loaded 3064_8.txt
# Loaded 8469_7.txt
# Loaded 7053_7.txt
# Loaded 9815_7.txt
# Loaded 9470_8.txt
# Loaded 6455_7.txt
# Loaded 5131_10.txt
# Loaded 2177_8.txt
# Loaded 6057_9.txt
# Loaded 12310_10.txt
# Loaded 5690_7.txt
# Loaded 173_7.txt
# Loaded 9770_10.txt
# Loaded 9756_10.txt
# Loaded 5404_10.txt
# Loaded 9491_10.txt
# Loaded 1388_10.txt
# Loaded 6616_7.txt
# Loaded 2787_8.txt
# Loaded 6041_10.txt
# Loaded 3270_8.txt
# Loaded 2061_9.txt
# Loaded 360_10.txt
# Loaded 10754_10.txt
# Loaded 394_8.txt
# Loaded 9325_10.txt
# Loaded 1927_8.txt
# Loaded 7302_10.txt
# Loaded 5217_8.txt
# Loaded 4560_10.txt
# Loaded 4718_7.txt
# Loaded 1993_10.txt
# Loaded 12158_7.txt
# Loaded 9912_10.txt
# Loaded 7124_8.txt
# Loaded 11962_7.txt
# Loaded 11312_9.txt
# Loaded 4538_7.txt
# Loaded 11343_8.txt
# Loaded 9303_8.txt
# Loaded 11879_10.txt
# Loaded 980_7.txt
# Loaded 5160_8.txt
# Loaded 1608_9.txt
# Loaded 5372_7.txt
# Loaded 2776_8.txt
# Loaded 1568_9.txt
# Loaded 6796_8.txt
# Loaded 2942_10.txt
# Loaded 1904_7.txt
# Loaded 10571_8.txt
# Loaded 8719_10.txt
# Loaded 12228_8.txt
# Loaded 2321_9.txt
# Loaded 8796_8.txt
# Loaded 11807_7.txt
# Loaded 608_8.txt
# Loaded 8323_10.txt
# Loaded 10239_10.txt
# Loaded 1788_7.txt
# Loaded 8416_7.txt
# Loaded 9740_7.txt
# Loaded 2175_9.txt
# Loaded 5439_10.txt
# Loaded 12068_9.txt
# Loaded 7566_10.txt
# Loaded 4173_10.txt
# Loaded 9250_8.txt
# Loaded 969_7.txt
# Loaded 1135_9.txt
# Loaded 4037_7.txt
# Loaded 7295_10.txt
# Loaded 9459_8.txt
# Loaded 933_10.txt
# Loaded 3376_9.txt
# Loaded 425_10.txt
# Loaded 5397_9.txt
# Loaded 3381_10.txt
# Loaded 3941_9.txt
# Loaded 3020_9.txt
# Loaded 315_10.txt
# Loaded 9321_8.txt
# Loaded 3320_8.txt
# Loaded 11532_8.txt
# Loaded 10323_10.txt
# Loaded 3556_10.txt
# Loaded 7703_8.txt
# Loaded 384_8.txt
# Loaded 8177_8.txt
# Loaded 10369_8.txt
# Loaded 6931_8.txt
# Loaded 4319_9.txt
# Loaded 12257_8.txt
# Loaded 5974_7.txt
# Loaded 7808_10.txt
# Loaded 4485_10.txt
# Loaded 9063_8.txt
# Loaded 8184_7.txt
# Loaded 8688_8.txt
# Loaded 290_9.txt
# Loaded 6155_7.txt
# Loaded 4546_10.txt
# Loaded 8217_8.txt
# Loaded 5631_8.txt
# Loaded 10352_10.txt
# Loaded 3406_10.txt
# Loaded 2130_10.txt
# Loaded 9574_9.txt
# Loaded 2166_7.txt
# Loaded 6292_10.txt
# Loaded 8671_7.txt
# Loaded 7988_10.txt
# Loaded 1133_10.txt
# Loaded 7481_10.txt
# Loaded 11325_10.txt
# Loaded 2600_10.txt
# Loaded 4577_10.txt
# Loaded 6643_7.txt
# Loaded 3764_8.txt
# Loaded 3913_10.txt
# Loaded 11337_10.txt
# Loaded 10724_8.txt
# Loaded 8878_9.txt
# Loaded 270_10.txt
# Loaded 10407_8.txt
# Loaded 11751_10.txt
# Loaded 7325_9.txt
# Loaded 3586_10.txt
# Loaded 1634_7.txt
# Loaded 6915_9.txt
# Loaded 8175_7.txt
# Loaded 3467_7.txt
# Loaded 6876_8.txt
# Loaded 1036_9.txt
# Loaded 2153_9.txt
# Loaded 7474_9.txt
# Loaded 2226_10.txt
# Loaded 9943_7.txt
# Loaded 1526_9.txt
# Loaded 439_9.txt
# Loaded 753_8.txt
# Loaded 2459_8.txt
# Loaded 11963_10.txt
# Loaded 2273_9.txt
# Loaded 3517_8.txt
# Loaded 9045_9.txt
# Loaded 7920_7.txt
# Loaded 2439_8.txt
# Loaded 2498_7.txt
# Loaded 6867_9.txt
# Loaded 3473_9.txt
# Loaded 3706_7.txt
# Loaded 7260_10.txt
# Loaded 703_10.txt
# Loaded 7168_10.txt
# Loaded 4518_9.txt
# Loaded 9495_8.txt
# Loaded 11629_10.txt
# Loaded 5390_9.txt
# Loaded 5046_10.txt
# Loaded 8083_7.txt
# Loaded 6000_9.txt
# Loaded 1037_8.txt
# Loaded 5410_7.txt
# Loaded 325_9.txt
# Loaded 12129_7.txt
# Loaded 11397_10.txt
# Loaded 1653_10.txt
# Loaded 7412_9.txt
# Loaded 10770_7.txt
# Loaded 8961_9.txt
# Loaded 11940_7.txt
# Loaded 8889_8.txt
# Loaded 1819_9.txt
# Loaded 9988_8.txt
# Loaded 9962_9.txt
# Loaded 7709_7.txt
# Loaded 10723_8.txt
# Loaded 7773_10.txt
# Loaded 2699_10.txt
# Loaded 1718_7.txt
# Loaded 10438_9.txt
# Loaded 4857_7.txt
# Loaded 11707_10.txt
# Loaded 11503_10.txt
# Loaded 948_10.txt
# Loaded 8637_10.txt
# Loaded 3286_10.txt
# Loaded 3384_8.txt
# Loaded 8583_9.txt
# Loaded 5711_8.txt
# Loaded 11537_7.txt
# Loaded 10932_7.txt
# Loaded 11982_7.txt
# Loaded 9513_10.txt
# Loaded 6354_10.txt
# Loaded 2658_10.txt
# Loaded 12223_10.txt
# Loaded 7071_9.txt
# Loaded 9698_10.txt
# Loaded 7598_10.txt
# Loaded 317_10.txt
# Loaded 8201_8.txt
# Loaded 3541_7.txt
# Loaded 7242_7.txt
# Loaded 4109_10.txt
# Loaded 6956_8.txt
# Loaded 10268_9.txt
# Loaded 12260_10.txt
# Loaded 11290_10.txt
# Loaded 9654_10.txt
# Loaded 7395_8.txt
# Loaded 9746_9.txt
# Loaded 9917_10.txt
# Loaded 7956_10.txt
# Loaded 4121_10.txt
# Loaded 5817_10.txt
# Loaded 2185_9.txt
# Loaded 3794_10.txt
# Loaded 11019_10.txt
# Loaded 9442_10.txt
# Loaded 11168_8.txt
# Loaded 5198_7.txt
# Loaded 2837_8.txt
# Loaded 8558_10.txt
# Loaded 6713_10.txt
# Loaded 5266_10.txt
# Loaded 895_10.txt
# Loaded 10148_10.txt
# Loaded 4853_10.txt
# Loaded 11959_8.txt
# Loaded 5960_8.txt
# Loaded 7044_10.txt
# Loaded 258_7.txt
# Loaded 9856_8.txt
# Loaded 11772_10.txt
# Loaded 3781_7.txt
# Loaded 6207_9.txt
# Loaded 1791_8.txt
# Loaded 24_8.txt
# Loaded 10836_10.txt
# Loaded 12008_8.txt
# Loaded 2648_8.txt
# Loaded 9147_10.txt
# Loaded 11719_7.txt
# Loaded 4931_8.txt
# Loaded 7032_10.txt
# Loaded 2133_10.txt
# Loaded 11357_10.txt
# Loaded 9392_9.txt
# Loaded 9634_8.txt
# Loaded 1537_9.txt
# Loaded 6332_8.txt
# Loaded 2821_9.txt
# Loaded 4722_8.txt
# Loaded 5732_7.txt
# Loaded 7379_9.txt
# Loaded 2276_7.txt
# Loaded 3115_8.txt
# Loaded 7910_10.txt
# Loaded 4781_8.txt
# Loaded 2677_9.txt
# Loaded 10556_10.txt
# Loaded 10134_7.txt
# Loaded 9532_10.txt
# Loaded 4797_10.txt
# Loaded 8227_7.txt
# Loaded 1530_10.txt
# Loaded 1072_10.txt
# Loaded 9627_10.txt
# Loaded 6994_8.txt
# Loaded 1480_8.txt
# Loaded 1139_8.txt
# Loaded 7370_7.txt
# Loaded 4685_7.txt
# Loaded 9327_8.txt
# Loaded 10105_8.txt
# Loaded 9304_9.txt
# Loaded 12237_10.txt
# Loaded 2563_10.txt
# Loaded 3858_10.txt
# Loaded 8945_10.txt
# Loaded 8698_10.txt
# Loaded 10457_8.txt
# Loaded 2778_8.txt
# Loaded 5678_10.txt
# Loaded 1935_10.txt
# Loaded 10390_10.txt
# Loaded 3096_10.txt
# Loaded 180_9.txt
# Loaded 11903_10.txt
# Loaded 9695_10.txt
# Loaded 10888_8.txt
# Loaded 10988_10.txt
# Loaded 6049_8.txt
# Loaded 6791_10.txt
# Loaded 12163_8.txt
# Loaded 3032_7.txt
# Loaded 3677_8.txt
# Loaded 2689_9.txt
# Loaded 1319_10.txt
# Loaded 10312_10.txt
# Loaded 12404_9.txt
# Loaded 369_10.txt
# Loaded 5610_7.txt
# Loaded 8913_9.txt
# Loaded 8725_10.txt
# Loaded 5805_9.txt
# Loaded 5582_9.txt
# Loaded 7569_10.txt
# Loaded 7417_10.txt
# Loaded 1953_10.txt
# Loaded 11974_10.txt
# Loaded 11949_8.txt
# Loaded 3190_7.txt
# Loaded 11231_10.txt
# Loaded 2451_8.txt
# Loaded 1908_9.txt
# Loaded 1406_8.txt
# Loaded 11320_10.txt
# Loaded 11988_8.txt
# Loaded 11313_10.txt
# Loaded 2353_10.txt
# Loaded 8159_10.txt
# Loaded 7878_7.txt
# Loaded 6568_9.txt
# Loaded 9516_8.txt
# Loaded 11632_7.txt
# Loaded 10481_8.txt
# Loaded 3958_7.txt
# Loaded 5655_7.txt
# Loaded 8829_9.txt
# Loaded 7002_10.txt
# Loaded 2937_10.txt
# Loaded 11631_7.txt
# Loaded 9683_9.txt
# Loaded 4202_10.txt
# Loaded 1416_10.txt
# Loaded 8333_9.txt
# Loaded 7350_8.txt
# Loaded 1962_10.txt
# Loaded 8098_7.txt
# Loaded 8825_9.txt
# Loaded 1749_10.txt
# Loaded 10960_8.txt
# Loaded 7215_7.txt
# Loaded 5648_10.txt
# Loaded 3837_9.txt
# Loaded 8764_8.txt
# Loaded 5577_8.txt
# Loaded 7767_8.txt
# Loaded 5041_8.txt
# Loaded 9834_10.txt
# Loaded 5573_10.txt
# Loaded 9510_8.txt
# Loaded 4971_7.txt
# Loaded 9583_8.txt
# Loaded 12427_7.txt
# Loaded 10493_9.txt
# Loaded 3000_8.txt
# Loaded 10657_8.txt
# Loaded 2257_7.txt
# Loaded 10684_9.txt
# Loaded 122_9.txt
# Loaded 5672_9.txt
# Loaded 7214_7.txt
# Loaded 3828_10.txt
# Loaded 6644_8.txt
# Loaded 564_8.txt
# Loaded 6834_10.txt
# Loaded 462_8.txt
# Loaded 3959_9.txt
# Loaded 1055_10.txt
# Loaded 10964_7.txt
# Loaded 303_10.txt
# Loaded 3487_9.txt
# Loaded 690_9.txt
# Loaded 11951_8.txt
# Loaded 5165_9.txt
# Loaded 11901_9.txt
# Loaded 5735_7.txt
# Loaded 6842_7.txt
# Loaded 3935_9.txt
# Loaded 3603_7.txt
# Loaded 4321_8.txt
# Loaded 10995_10.txt
# Loaded 132_9.txt
# Loaded 6389_9.txt
# Loaded 10377_9.txt
# Loaded 9353_8.txt
# Loaded 8147_10.txt
# Loaded 7436_10.txt
# Loaded 2851_10.txt
# Loaded 9231_8.txt
# Loaded 8206_10.txt
# Loaded 3148_9.txt
# Loaded 4787_10.txt
# Loaded 667_8.txt
# Loaded 1968_8.txt
# Loaded 449_10.txt
# Loaded 1466_10.txt
# Loaded 8475_10.txt
# Loaded 5088_8.txt
# Loaded 6029_7.txt
# Loaded 2547_10.txt
# Loaded 2461_10.txt
# Loaded 11023_9.txt
# Loaded 6424_10.txt
# Loaded 9804_10.txt
# Loaded 5699_8.txt
# Loaded 7640_10.txt
# Loaded 4581_10.txt
# Loaded 12469_10.txt
# Loaded 6770_10.txt
# Loaded 7682_8.txt
# Loaded 2671_7.txt
# Loaded 8569_9.txt
# Loaded 193_7.txt
# Loaded 10016_8.txt
# Loaded 488_9.txt
# Loaded 6143_7.txt
# Loaded 10054_10.txt
# Loaded 9270_9.txt
# Loaded 175_7.txt
# Loaded 7091_9.txt
# Loaded 10538_8.txt
# Loaded 9623_7.txt
# Loaded 4523_10.txt
# Loaded 7927_10.txt
# Loaded 154_8.txt
# Loaded 10119_7.txt
# Loaded 3204_10.txt
# Loaded 10512_10.txt
# Loaded 8368_10.txt
# Loaded 1860_9.txt
# Loaded 7726_10.txt
# Loaded 617_7.txt
# Loaded 4356_8.txt
# Loaded 4514_10.txt
# Loaded 9192_7.txt
# Loaded 10215_10.txt
# Loaded 3344_9.txt
# Loaded 1112_8.txt
# Loaded 10879_10.txt
# Loaded 5257_10.txt
# Loaded 7272_10.txt
# Loaded 4792_10.txt
# Loaded 5889_7.txt
# Loaded 11725_10.txt
# Loaded 9707_10.txt
# Loaded 3661_10.txt
# Loaded 9837_7.txt
# Loaded 2423_7.txt
# Loaded 697_8.txt
# Loaded 9539_7.txt
# Loaded 1584_9.txt
# Loaded 8327_9.txt
# Loaded 3755_10.txt
# Loaded 11432_9.txt
# Loaded 2240_7.txt
# Loaded 7292_10.txt
# Loaded 8968_8.txt
# Loaded 7801_9.txt
# Loaded 1782_7.txt
# Loaded 9409_8.txt
# Loaded 9396_9.txt
# Loaded 9277_9.txt
# Loaded 2058_9.txt
# Loaded 9769_8.txt
# Loaded 11160_9.txt
# Loaded 3296_10.txt
# Loaded 7825_9.txt
# Loaded 6398_8.txt
# Loaded 10420_10.txt
# Loaded 9178_10.txt
# Loaded 11187_9.txt
# Loaded 1765_8.txt
# Loaded 4900_8.txt
# Loaded 7144_10.txt
# Loaded 9572_8.txt
# Loaded 12298_8.txt
# Loaded 5183_9.txt
# Loaded 6526_7.txt
# Loaded 8424_9.txt
# Loaded 7066_8.txt
# Loaded 5664_8.txt
# Loaded 9051_10.txt
# Loaded 9341_7.txt
# Loaded 11696_7.txt
# Loaded 1126_9.txt
# Loaded 7102_7.txt
# Loaded 8775_9.txt
# Loaded 7357_10.txt
# Loaded 1184_7.txt
# Loaded 7301_7.txt
# Loaded 4320_8.txt
# Loaded 1447_8.txt
# Loaded 4563_8.txt
# Loaded 11457_10.txt
# Loaded 3805_8.txt
# Loaded 8059_10.txt
# Loaded 6705_10.txt
# Loaded 7975_8.txt
# Loaded 8938_9.txt
# Loaded 7879_7.txt
# Loaded 950_9.txt
# Loaded 12445_9.txt
# Loaded 8048_7.txt
# Loaded 907_8.txt
# Loaded 8899_8.txt
# Loaded 6216_7.txt
# Loaded 12041_9.txt
# Loaded 7952_8.txt
# Loaded 10566_8.txt
# Loaded 9520_10.txt
# Loaded 6941_9.txt
# Loaded 1784_10.txt
# Loaded 276_10.txt
# Loaded 6553_10.txt
# Loaded 6807_10.txt
# Loaded 3446_7.txt
# Loaded 5251_7.txt
# Loaded 9720_8.txt
# Loaded 11182_10.txt
# Loaded 1721_8.txt
# Loaded 3701_10.txt
# Loaded 2468_10.txt
# Loaded 8736_10.txt
# Loaded 2843_7.txt
# Loaded 12307_10.txt
# Loaded 10158_7.txt
# Loaded 452_10.txt
# Loaded 9022_10.txt
# Loaded 11456_10.txt
# Loaded 10658_10.txt
# Loaded 2727_9.txt
# Loaded 8563_10.txt
# Loaded 7060_10.txt
# Loaded 1565_7.txt
# Loaded 12190_7.txt
# Loaded 7924_9.txt
# Loaded 11806_10.txt
# Loaded 6464_9.txt
# Loaded 4445_7.txt
# Loaded 5465_8.txt
# Loaded 5234_10.txt
# Loaded 9561_8.txt
# Loaded 9639_10.txt
# Loaded 10039_10.txt
# Loaded 3910_10.txt
# Loaded 5085_7.txt
# Loaded 4434_7.txt
# Loaded 10144_8.txt
# Loaded 5067_10.txt
# Loaded 139_10.txt
# Loaded 1001_8.txt
# Loaded 2180_8.txt
# Loaded 4294_8.txt
# Loaded 1470_10.txt
# Loaded 2120_8.txt
# Loaded 5177_8.txt
# Loaded 5058_10.txt
# Loaded 10365_8.txt
# Loaded 4416_9.txt
# Loaded 116_10.txt
# Loaded 9375_10.txt
# Loaded 2471_10.txt
# Loaded 8533_8.txt
# Loaded 7234_8.txt
# Loaded 3549_8.txt
# Loaded 11165_8.txt
# Loaded 4400_10.txt
# Loaded 12247_8.txt
# Loaded 7040_10.txt
# Loaded 5329_9.txt
# Loaded 9404_10.txt
# Loaded 4020_10.txt
# Loaded 4426_7.txt
# Loaded 10962_10.txt
# Loaded 10071_9.txt
# Loaded 11868_10.txt
# Loaded 8411_7.txt
# Loaded 12050_10.txt
# Loaded 1756_7.txt
# Loaded 8624_7.txt
# Loaded 2427_10.txt
# Loaded 789_7.txt
# Loaded 902_9.txt
# Loaded 5352_7.txt
# Loaded 189_9.txt
# Loaded 5950_10.txt
# Loaded 9476_9.txt
# Loaded 2093_7.txt
# Loaded 5383_10.txt
# Loaded 2016_7.txt
# Loaded 1279_9.txt
# Loaded 8453_10.txt
# Loaded 8605_10.txt
# Loaded 4982_7.txt
# Loaded 967_7.txt
# Loaded 7509_8.txt
# Loaded 8029_10.txt
# Loaded 4146_10.txt
# Loaded 10786_10.txt
# Loaded 9659_8.txt
# Loaded 9569_9.txt
# Loaded 7754_9.txt
# Loaded 9905_10.txt
# Loaded 6001_7.txt
# Loaded 11643_7.txt
# Loaded 7487_8.txt
# Loaded 8389_8.txt
# Loaded 6891_9.txt
# Loaded 7563_10.txt
# Loaded 10437_7.txt
# Loaded 5163_7.txt
# Loaded 3312_8.txt
# Loaded 1648_10.txt
# Loaded 9552_8.txt
# Loaded 6433_7.txt
# Loaded 3050_9.txt
# Loaded 12018_7.txt
# Loaded 11422_8.txt
# Loaded 2685_10.txt
# Loaded 6425_9.txt
# Loaded 2914_8.txt
# Loaded 9112_9.txt
# Loaded 3589_8.txt
# Loaded 598_9.txt
# Loaded 8392_8.txt
# Loaded 12280_9.txt
# Loaded 2841_10.txt
# Loaded 12422_8.txt
# Loaded 8771_7.txt
# Loaded 12131_7.txt
# Loaded 9704_10.txt
# Loaded 1391_7.txt
# Loaded 7461_10.txt
# Loaded 11323_10.txt
# Loaded 6172_7.txt
# Loaded 9887_9.txt
# Loaded 3899_9.txt
# Loaded 4771_10.txt
# Loaded 8615_10.txt
# Loaded 7428_10.txt
# Loaded 399_9.txt
# Loaded 1365_8.txt
# Loaded 10121_8.txt
# Loaded 5707_10.txt
# Loaded 6894_7.txt
# Loaded 9073_10.txt
# Loaded 6279_10.txt
# Loaded 765_9.txt
# Loaded 7763_8.txt
# Loaded 7427_9.txt
# Loaded 7167_9.txt
# Loaded 6294_10.txt
# Loaded 8715_10.txt
# Loaded 510_8.txt
# Loaded 9534_10.txt
# Loaded 9543_7.txt
# Loaded 7659_10.txt
# Loaded 5744_7.txt
# Loaded 10282_8.txt
# Loaded 7557_9.txt
# Loaded 8214_7.txt
# Loaded 2288_9.txt
# Loaded 1196_8.txt
# Loaded 11562_9.txt
# Loaded 11493_7.txt
# Loaded 6782_9.txt
# Loaded 6541_8.txt
# Loaded 12425_7.txt
# Loaded 10015_8.txt
# Loaded 1524_7.txt
# Loaded 7670_8.txt
# Loaded 2514_8.txt
# Loaded 6628_7.txt
# Loaded 5768_8.txt
# Loaded 9002_9.txt
# Loaded 6344_7.txt
# Loaded 11113_9.txt
# Loaded 11340_7.txt
# Loaded 3658_10.txt
# Loaded 3155_10.txt
# Loaded 4904_10.txt
# Loaded 2719_10.txt
# Loaded 10298_9.txt
# Loaded 11812_10.txt
# Loaded 9653_9.txt
# Loaded 1000_8.txt
# Loaded 11427_10.txt
# Loaded 9336_9.txt
# Loaded 5171_10.txt
# Loaded 5729_9.txt
# Loaded 3810_9.txt
# Loaded 364_10.txt
# Loaded 4620_10.txt
# Loaded 54_10.txt
# Loaded 4417_9.txt
# Loaded 5142_10.txt
# Loaded 6880_7.txt
# Loaded 5309_7.txt
# Loaded 8222_9.txt
# Loaded 1787_10.txt
# ...
# Loaded 11946_3.txt
# Loaded 2443_4.txt
# Loaded 3596_3.txt
# Loaded 12370_1.txt
# Loaded 10238_2.txt
# Loaded 1292_3.txt
# Loaded 10234_3.txt
# Loaded 5986_2.txt
# Loaded 856_3.txt
# Loaded 5474_3.txt
# Loaded 1646_1.txt
# Loaded 4835_1.txt
# Loaded 12250_2.txt
# Loaded 3679_2.txt
# Loaded 8755_2.txt
# Loaded 234_3.txt
# Loaded 4342_2.txt
# Loaded 8322_4.txt
# Loaded 11943_4.txt
# Loaded 4398_3.txt
# Loaded 11500_4.txt
# Loaded 7702_2.txt
# Loaded 10013_4.txt
# Loaded 9938_3.txt
# Loaded 2317_2.txt
# Loaded 4693_1.txt
# Loaded 10115_1.txt
# Loaded 8883_3.txt
# Loaded 4370_2.txt
# Loaded 5650_2.txt
# Loaded 12442_1.txt
# Loaded 6701_4.txt
# Loaded 2336_1.txt
# Loaded 10636_3.txt
# Loaded 1730_1.txt
# Loaded 3073_2.txt
# Loaded 7981_4.txt
# Loaded 11089_1.txt
# Loaded 2194_4.txt
# Loaded 5498_1.txt
# Loaded 860_4.txt
# Loaded 5189_1.txt
# Loaded 2852_2.txt
# Loaded 6401_1.txt
# Loaded 6987_2.txt
# Loaded 8216_2.txt
# Loaded 2348_3.txt
# Loaded 908_3.txt
# Loaded 8159_4.txt
# Loaded 4052_2.txt
# Loaded 10876_1.txt
# Loaded 6882_4.txt
# Loaded 4644_2.txt
# Loaded 1437_1.txt
# Loaded 7771_1.txt
# Loaded 5576_1.txt
# Loaded 9119_1.txt
# Loaded 11819_2.txt
# Loaded 7732_2.txt
# Loaded 3785_3.txt
# Loaded 3110_1.txt
# Loaded 1661_1.txt
# Loaded 952_1.txt
# Loaded 8268_4.txt
# Loaded 3006_2.txt
# Loaded 6100_1.txt
# Loaded 1606_1.txt
# Loaded 6926_4.txt
# Loaded 943_3.txt
# Loaded 7387_3.txt
# Loaded 3737_3.txt
# Loaded 6875_1.txt
# Loaded 11323_2.txt
# Loaded 8519_3.txt
# Loaded 6268_1.txt
# Loaded 2544_2.txt
# Loaded 5319_4.txt
# Loaded 6487_1.txt
# Loaded 10684_3.txt
# Loaded 1231_4.txt
# Loaded 12220_1.txt
# Loaded 3116_2.txt
# Loaded 12348_1.txt
# Loaded 1755_1.txt
# Loaded 10213_4.txt
# Loaded 4985_4.txt
# Loaded 1863_1.txt
# Loaded 11894_1.txt
# Loaded 7898_1.txt
# Loaded 6450_1.txt
# Loaded 10594_1.txt
# Loaded 1625_3.txt
# Loaded 1275_3.txt
# Loaded 9228_4.txt
# Loaded 5305_3.txt
# Loaded 9830_2.txt
# Loaded 1104_4.txt
# Loaded 1051_1.txt
# Loaded 5657_1.txt
# Loaded 569_4.txt
# Loaded 5481_1.txt
# Loaded 7546_1.txt
# Loaded 3088_3.txt
# Loaded 8144_3.txt
# Loaded 12189_1.txt
# Loaded 10118_1.txt
# Loaded 6255_1.txt
# Loaded 12158_2.txt
# Loaded 10806_3.txt
# Loaded 11430_4.txt
# Loaded 1204_1.txt
# Loaded 2708_2.txt
# Loaded 6645_1.txt
# Loaded 6435_2.txt
# Loaded 4227_1.txt
# Loaded 10526_2.txt
# Loaded 7748_2.txt
# Loaded 3174_1.txt
# Loaded 3819_4.txt
# Loaded 7564_3.txt
# Loaded 3953_2.txt
# Loaded 8312_4.txt
# Loaded 10428_1.txt
# Loaded 5944_4.txt
# Loaded 5854_4.txt
# Loaded 2650_2.txt
# Loaded 9816_3.txt
# Loaded 7475_1.txt
# Loaded 1221_1.txt
# Loaded 7189_2.txt
# Loaded 7941_1.txt
# Loaded 3304_2.txt
# Loaded 2092_2.txt
# Loaded 5642_1.txt
# Loaded 2234_4.txt
# Loaded 3218_1.txt
# Loaded 1432_3.txt
# Loaded 10007_4.txt
# Loaded 5321_4.txt
# Loaded 8760_1.txt
# Loaded 5575_1.txt
# Loaded 8966_4.txt
# Loaded 9607_1.txt
# Loaded 7972_1.txt
# Loaded 3042_3.txt
# Loaded 4211_3.txt
# Loaded 3349_4.txt
# Loaded 10402_3.txt
# Loaded 5989_4.txt
# Loaded 1718_2.txt
# Loaded 11807_3.txt
# Loaded 50_3.txt
# Loaded 8139_4.txt
# Loaded 4356_3.txt
# Loaded 3711_2.txt
# Loaded 10709_3.txt
# Loaded 4694_4.txt
# Loaded 6399_3.txt
# Loaded 8982_1.txt
# Loaded 7529_3.txt
# Loaded 1198_4.txt
# Loaded 6060_2.txt
# Loaded 2461_4.txt
# Loaded 8530_3.txt
# Loaded 5802_4.txt
# Loaded 5064_3.txt
# Loaded 1644_4.txt
# Loaded 10830_1.txt
# Loaded 10508_1.txt
# Loaded 11125_3.txt
# Loaded 8805_2.txt
# Loaded 10258_1.txt
# Loaded 10974_2.txt
# Loaded 7350_1.txt
# Loaded 10154_2.txt
# Loaded 7260_2.txt
# Loaded 10839_4.txt
# Loaded 7969_3.txt
# Loaded 11841_1.txt
# Loaded 83_1.txt
# Loaded 11434_1.txt
# Loaded 12421_3.txt
# Loaded 1323_3.txt
# Loaded 2316_3.txt
# Loaded 7958_4.txt
# Loaded 11253_4.txt
# Loaded 11195_2.txt
# Loaded 5001_1.txt
# Loaded 6252_1.txt
# Loaded 11509_1.txt
# Loaded 3615_1.txt
# Loaded 457_2.txt
# Loaded 6335_3.txt
# Loaded 1666_3.txt
# Loaded 9029_4.txt
# Loaded 7646_1.txt
# Loaded 3449_1.txt
# Loaded 709_4.txt
# Loaded 5955_2.txt
# Loaded 8040_4.txt
# Loaded 7386_4.txt
# Loaded 9828_4.txt
# Loaded 5699_1.txt
# Loaded 3352_4.txt
# Loaded 2196_1.txt
# Loaded 1811_3.txt
# Loaded 6029_1.txt
# Loaded 10088_1.txt
# Loaded 1461_3.txt
# Loaded 6644_1.txt
# Loaded 11232_2.txt
# Loaded 6445_3.txt
# Loaded 1598_1.txt
# Loaded 4839_1.txt
# Loaded 8634_1.txt
# Loaded 1567_1.txt
# Loaded 8598_1.txt
# Loaded 3537_2.txt
# Loaded 12211_3.txt
# Loaded 2490_1.txt
# Loaded 5464_1.txt
# Loaded 3332_3.txt
# Loaded 8340_4.txt
# Loaded 2572_1.txt
# Loaded 9205_1.txt
# Loaded 699_1.txt
# Loaded 8288_4.txt
# Loaded 1386_1.txt
# Loaded 5570_2.txt
# Loaded 6027_4.txt
# Loaded 11180_4.txt
# Loaded 9573_4.txt
# Loaded 3112_1.txt
# Loaded 12132_4.txt
# Loaded 2327_2.txt
# Loaded 7926_4.txt
# Loaded 3147_1.txt
# Loaded 8790_1.txt
# Loaded 11024_2.txt
# Loaded 3328_4.txt
# Loaded 295_1.txt
# Loaded 6748_3.txt
# Loaded 10385_1.txt
# Loaded 4029_1.txt
# Loaded 8545_3.txt
# Loaded 10592_1.txt
# Loaded 11858_1.txt
# Loaded 7787_3.txt
# Loaded 2597_1.txt
# Loaded 8693_2.txt
# Loaded 11062_2.txt
# Loaded 9603_1.txt
# Loaded 11557_1.txt
# Loaded 12156_4.txt
# Loaded 1986_1.txt
# Loaded 830_4.txt
# Loaded 4481_1.txt
# Loaded 9118_1.txt
# Loaded 590_1.txt
# Loaded 996_3.txt
# Loaded 5908_4.txt
# Loaded 8132_3.txt
# Loaded 11130_1.txt
# Loaded 9710_2.txt
# Loaded 650_3.txt
# Loaded 4461_4.txt
# Loaded 10991_1.txt
# Loaded 4947_1.txt
# Loaded 11173_2.txt
# Loaded 2520_3.txt
# Loaded 9240_2.txt
# Loaded 5176_1.txt
# Loaded 4126_1.txt
# Loaded 7578_2.txt
# Loaded 11572_2.txt
# Loaded 12044_4.txt
# Loaded 4492_2.txt
# Loaded 2389_2.txt
# Loaded 2011_1.txt
# Loaded 7673_1.txt
# Loaded 11146_2.txt
# Loaded 6406_4.txt
# Loaded 4417_1.txt
# Loaded 8437_1.txt
# Loaded 12476_4.txt
# Loaded 3457_1.txt
# Loaded 1923_1.txt
# Loaded 8525_2.txt
# Loaded 5337_3.txt
# Loaded 7919_2.txt
# Loaded 7580_3.txt
# Loaded 308_1.txt
# Loaded 309_3.txt
# Loaded 949_3.txt
# Loaded 3936_3.txt
# Loaded 10660_4.txt
# Loaded 3526_3.txt
# Loaded 6707_4.txt
# Loaded 6219_1.txt
# Loaded 7868_1.txt
# Loaded 393_1.txt
# Loaded 4165_1.txt
# Loaded 6714_4.txt
# Loaded 9484_2.txt
# Loaded 10858_1.txt
# Loaded 10000_4.txt
# Loaded 299_1.txt
# Loaded 8343_4.txt
# Loaded 10168_4.txt
# Loaded 11395_4.txt
# Loaded 10202_4.txt
# Loaded 343_1.txt
# Loaded 6136_4.txt
# Loaded 2913_3.txt
# Loaded 741_1.txt
# Loaded 6158_2.txt
# Loaded 8853_1.txt
# Loaded 5014_1.txt
# Loaded 3121_1.txt
# Loaded 6015_1.txt
# Loaded 8176_4.txt
# Loaded 3220_3.txt
# Loaded 7742_1.txt
# Loaded 922_3.txt
# Loaded 11818_4.txt
# Loaded 1346_1.txt
# Loaded 7925_2.txt
# Loaded 3984_1.txt
# Loaded 7662_1.txt
# Loaded 7122_1.txt
# Loaded 9256_2.txt
# Loaded 10734_2.txt
# Loaded 8107_2.txt
# Loaded 1785_1.txt
# Loaded 11117_1.txt
# Loaded 7992_1.txt
# Loaded 5010_1.txt
# Loaded 1038_1.txt
# Loaded 775_1.txt
# Loaded 5153_4.txt
# Loaded 8794_1.txt
# Loaded 704_2.txt
# Loaded 6853_3.txt
# Loaded 3300_1.txt
# Loaded 613_4.txt
# Loaded 12297_2.txt
# Loaded 11421_3.txt
# Loaded 8748_2.txt
# Loaded 12474_4.txt
# Loaded 10864_1.txt
# Loaded 11929_4.txt
# Loaded 1823_2.txt
# Loaded 5579_3.txt
# Loaded 392_2.txt
# Loaded 10463_2.txt
# Loaded 5525_1.txt
# Loaded 4359_1.txt
# Loaded 8097_2.txt
# Loaded 5131_3.txt
# Loaded 11851_1.txt
# Loaded 2419_1.txt
# Loaded 422_3.txt
# Loaded 11286_1.txt
# Loaded 6850_2.txt
# Loaded 10573_3.txt
# Loaded 10785_4.txt
# Loaded 9238_3.txt
# Loaded 4023_3.txt
# Loaded 5522_3.txt
# Loaded 3397_3.txt
# Loaded 2709_3.txt
# Loaded 3313_4.txt
# Loaded 4193_1.txt
# Loaded 10208_1.txt
# Loaded 601_3.txt
# Loaded 9727_2.txt
# Loaded 5881_1.txt
# Loaded 5517_2.txt
# Loaded 10520_2.txt
# Loaded 2662_1.txt
# Loaded 1791_1.txt
# Loaded 824_4.txt
# Loaded 9445_1.txt
# Loaded 6065_4.txt
# Loaded 10621_2.txt
# Loaded 3904_2.txt
# Loaded 11085_1.txt
# Loaded 6251_1.txt
# Loaded 11150_3.txt
# Loaded 1952_1.txt
# Loaded 10816_2.txt
# Loaded 10735_1.txt
# Loaded 3853_1.txt
# Loaded 5893_1.txt
# Loaded 12457_3.txt
# Loaded 6391_1.txt
# Loaded 7489_2.txt
# Loaded 246_2.txt
# Loaded 9060_3.txt
# Loaded 12140_3.txt
# Loaded 4498_4.txt
# Loaded 7718_2.txt
# Loaded 5117_1.txt
# Loaded 8380_4.txt
# Loaded 10898_2.txt
# Loaded 9699_1.txt
# Loaded 11855_1.txt
# Loaded 2027_1.txt
# Loaded 3005_1.txt
# Loaded 9123_3.txt
# Loaded 3215_2.txt
# Loaded 2319_1.txt
# Loaded 1973_4.txt
# Loaded 11360_4.txt
# Loaded 7518_4.txt
# Loaded 2489_3.txt
# Loaded 11693_3.txt
# Loaded 4076_3.txt
# Loaded 8130_4.txt
# Loaded 5848_4.txt
# Loaded 3751_1.txt
# Loaded 923_4.txt
# Loaded 815_3.txt
# Loaded 7539_2.txt
# Loaded 6223_2.txt
# Loaded 3579_1.txt
# Loaded 6953_1.txt
# Loaded 2771_3.txt
# Loaded 10356_1.txt
# Loaded 10797_1.txt
# Loaded 8264_3.txt
# Loaded 7010_4.txt
# Loaded 2529_1.txt
# Loaded 5180_1.txt
# Loaded 3191_4.txt
# Loaded 2663_1.txt
# Loaded 12177_2.txt
# Loaded 10244_2.txt
# Loaded 8009_2.txt
# Loaded 8723_1.txt
# Loaded 7268_1.txt
# Loaded 2870_1.txt
# Loaded 642_2.txt
# Loaded 6275_1.txt
# Loaded 7148_1.txt
# Loaded 2637_1.txt
# Loaded 5628_1.txt
# Loaded 721_4.txt
# Loaded 8622_2.txt
# Loaded 7034_3.txt
# Loaded 5962_3.txt
# Loaded 4720_3.txt
# Loaded 4288_1.txt
# Loaded 3111_1.txt
# Loaded 10490_1.txt
# Loaded 11015_3.txt
# Loaded 10079_1.txt
# Loaded 1492_3.txt
# Loaded 6446_4.txt
# Loaded 10106_1.txt
# Loaded 10988_3.txt
# Loaded 6765_3.txt
# Loaded 10075_3.txt
# Loaded 10757_4.txt
# Loaded 10466_3.txt
# Loaded 10817_4.txt
# Loaded 214_1.txt
# Loaded 4366_1.txt
# Loaded 6291_1.txt
# Loaded 3728_1.txt
# Loaded 8660_1.txt
# Loaded 5181_1.txt
# Loaded 5263_1.txt
# Loaded 8619_3.txt
# Loaded 1453_2.txt
# Loaded 12043_2.txt
# Loaded 11093_3.txt
# Loaded 4273_4.txt
# Loaded 12061_1.txt
# Loaded 1865_3.txt
# Loaded 9450_1.txt
# Loaded 10795_1.txt
# Loaded 2570_4.txt
# Loaded 7883_1.txt
# Loaded 10113_1.txt
# Loaded 9873_2.txt
# Loaded 7557_4.txt
# Loaded 9251_2.txt
# Loaded 12497_4.txt
# Loaded 3137_1.txt
# Loaded 1525_1.txt
# Loaded 2729_1.txt
# Loaded 4894_3.txt
# Loaded 3455_4.txt
# Loaded 8923_2.txt
# Loaded 2364_4.txt
# Loaded 7009_1.txt
# Loaded 9209_3.txt
# Loaded 3512_1.txt
# Loaded 9009_3.txt
# Loaded 7943_2.txt
# Loaded 5357_2.txt
# Loaded 4850_4.txt
# Loaded 2235_4.txt
# Loaded 4182_1.txt
# Loaded 7467_4.txt
# Loaded 12414_1.txt
# Loaded 1781_1.txt
# Loaded 8632_2.txt
# Loaded 1109_1.txt
# Loaded 5625_2.txt
# Loaded 2595_2.txt
# Loaded 10893_4.txt
# Loaded 6198_4.txt
# Loaded 3432_1.txt
# Loaded 6704_1.txt
# Loaded 1948_1.txt
# Loaded 11313_1.txt
# Loaded 3697_1.txt
# Loaded 3298_1.txt
# Loaded 3034_1.txt
# Loaded 790_1.txt
# Loaded 6072_3.txt
# Loaded 6616_2.txt
# Loaded 9103_1.txt
# Loaded 1509_2.txt
# Loaded 3828_1.txt
# Loaded 8398_1.txt
# Loaded 869_1.txt
# Loaded 7286_3.txt
# Loaded 7156_4.txt
# Loaded 7444_4.txt
# Loaded 7617_1.txt
# Loaded 4975_3.txt
# Loaded 6236_2.txt
# Loaded 2179_4.txt
# Loaded 10109_1.txt
# Loaded 9326_3.txt
# Loaded 2760_1.txt
# Loaded 3894_2.txt
# Loaded 5206_3.txt
# Loaded 10553_1.txt
# Loaded 5516_3.txt
# Loaded 12091_1.txt
# Loaded 2002_1.txt
# Loaded 9485_3.txt
# Loaded 9023_3.txt
# Loaded 5550_3.txt
# Loaded 8734_4.txt
# Loaded 2640_3.txt
# Loaded 10687_4.txt
# Loaded 1722_2.txt
# Loaded 7964_1.txt
# Loaded 7413_4.txt
# Loaded 8326_4.txt
# Loaded 11692_1.txt
# Loaded 2842_4.txt
# Loaded 328_4.txt
# Loaded 11366_3.txt
# Loaded 4658_4.txt
# Loaded 8199_1.txt
# Loaded 5178_3.txt
# Loaded 3745_3.txt
# Loaded 9819_4.txt
# Loaded 258_1.txt
# Loaded 9096_3.txt
# Loaded 6012_3.txt
# Loaded 10865_2.txt
# Loaded 7500_1.txt
# Loaded 1416_1.txt
# Loaded 12328_1.txt
# Loaded 2004_1.txt
# Loaded 9613_1.txt
# Loaded 6614_2.txt
# Loaded 9130_4.txt
# Loaded 8396_2.txt
# Loaded 3350_1.txt
# Loaded 11884_2.txt
# Loaded 1628_1.txt
# Loaded 4686_1.txt
# Loaded 9481_4.txt
# Loaded 10444_1.txt
# Loaded 1941_1.txt
# Loaded 6055_1.txt
# Loaded 1902_4.txt
# Loaded 6536_1.txt
# Loaded 4803_4.txt
# Loaded 9339_3.txt
# Loaded 7775_2.txt
# Loaded 10004_2.txt
# Loaded 6985_1.txt
# Loaded 42_4.txt
# Loaded 1782_1.txt
# Loaded 3384_3.txt
# Loaded 6001_3.txt
# Loaded 2210_4.txt
# Loaded 6332_4.txt
# Loaded 8367_4.txt
# Loaded 7464_1.txt
# Loaded 2495_2.txt
# Loaded 8873_4.txt
# Loaded 3252_2.txt
# Loaded 3556_4.txt
# Loaded 4756_4.txt
# Loaded 6054_1.txt
# Loaded 1570_2.txt
# Loaded 2058_2.txt
# Loaded 1655_1.txt
# Loaded 1005_2.txt
# Loaded 588_2.txt
# Loaded 5895_3.txt
# Loaded 2854_1.txt
# Loaded 734_1.txt
# Loaded 9661_3.txt
# Loaded 1150_2.txt
# Loaded 1079_1.txt
# Loaded 4477_1.txt
# Loaded 7253_1.txt
# Loaded 2853_1.txt
# Loaded 11635_4.txt
# Loaded 2395_3.txt
# Loaded 5491_4.txt
# Loaded 3064_1.txt
# Loaded 1766_2.txt
# Loaded 7828_1.txt
# Loaded 10228_1.txt
# Loaded 11657_4.txt
# Loaded 4096_1.txt
# Loaded 941_2.txt
# Loaded 7850_4.txt
# Loaded 2468_1.txt
# Loaded 2866_1.txt
# Loaded 10611_3.txt
# Loaded 954_4.txt
# Loaded 5234_1.txt
# Loaded 12105_1.txt
# Loaded 10613_1.txt
# Loaded 3621_2.txt
# Loaded 8256_4.txt
# Loaded 9977_1.txt
# Loaded 12077_2.txt
# Loaded 5291_1.txt
# Loaded 7741_4.txt
# Loaded 4824_1.txt
# Loaded 4306_3.txt
# Loaded 7204_1.txt
# Loaded 11802_1.txt
# Loaded 5612_4.txt
# Loaded 1347_3.txt
# Loaded 3265_1.txt
# Loaded 6576_1.txt
# Loaded 12462_1.txt
# Loaded 2412_2.txt
# Loaded 8227_2.txt
# Loaded 12311_1.txt
# Loaded 7507_1.txt
# Loaded 6735_1.txt
# Loaded 1479_4.txt
# Loaded 3451_3.txt
# Loaded 643_4.txt
# Loaded 4877_1.txt
# Loaded 4649_1.txt
# Loaded 11883_4.txt
# Loaded 2599_1.txt
# Loaded 11273_4.txt
# Loaded 10904_3.txt
# Loaded 6457_2.txt
# Loaded 1693_4.txt
# Loaded 6982_1.txt
# Loaded 3754_1.txt
# Loaded 7676_3.txt
# Loaded 5182_3.txt
# Loaded 7421_1.txt
# Loaded 11956_2.txt
# Loaded 6386_4.txt
# Loaded 199_4.txt
# Loaded 10964_4.txt
# Loaded 9464_1.txt
# Loaded 9502_4.txt
# Loaded 6980_1.txt
# Loaded 7699_1.txt
# Loaded 9433_1.txt
# Loaded 5120_2.txt
# Loaded 8190_2.txt
# Loaded 7180_4.txt
# Loaded 6846_1.txt
# Loaded 1996_4.txt
# Loaded 574_4.txt
# Loaded 9992_4.txt
# Loaded 5427_2.txt
# Loaded 7114_1.txt
# Loaded 10510_2.txt
# Loaded 4301_1.txt
# Loaded 6908_1.txt
# Loaded 13_1.txt
# Loaded 1061_1.txt
# Loaded 1988_1.txt
# Loaded 8999_2.txt
# Loaded 1070_1.txt
# Loaded 12054_2.txt
# Loaded 500_1.txt
# Loaded 8160_3.txt
# Loaded 9662_1.txt
# Loaded 579_1.txt
# Loaded 11725_4.txt
# Loaded 1228_4.txt
# Loaded 1689_1.txt
# Loaded 5006_4.txt
# Loaded 9681_1.txt
# Loaded 2649_2.txt
# Loaded 10108_1.txt
# Loaded 6111_3.txt
# Loaded 6350_1.txt
# Loaded 3322_1.txt
# Loaded 9112_3.txt
# Loaded 12277_4.txt
# Loaded 9467_4.txt
# Loaded 12351_1.txt
# Loaded 3840_4.txt
# Loaded 8303_4.txt
# Loaded 124_2.txt
# Loaded 1631_1.txt
# Loaded 944_2.txt
# Loaded 12278_3.txt
# Loaded 9963_3.txt
# Loaded 2904_4.txt
# Loaded 11597_1.txt
# Loaded 9167_3.txt
# Loaded 11379_2.txt
# Loaded 9639_2.txt
# Loaded 2990_1.txt
# Loaded 6464_4.txt
# Loaded 10183_1.txt
# Loaded 4924_4.txt
# Loaded 4744_1.txt
# Loaded 2826_2.txt
# Loaded 9930_3.txt
# Loaded 11794_1.txt
# Loaded 8902_1.txt
# Loaded 2104_2.txt
# Loaded 5700_1.txt
# Loaded 10139_1.txt
# Loaded 5091_1.txt
# Loaded 123_4.txt
# Loaded 5896_1.txt
# Loaded 1993_4.txt
# Loaded 8642_1.txt
# Loaded 7131_1.txt
# Loaded 462_4.txt
# Loaded 4791_1.txt
# Loaded 5740_4.txt
# Loaded 8914_1.txt
# Loaded 597_4.txt
# Loaded 11368_1.txt
# Loaded 9928_3.txt
# Loaded 7854_1.txt
# Loaded 4792_2.txt
# Loaded 210_4.txt
# Loaded 1500_2.txt
# Loaded 5995_3.txt
# Loaded 6234_3.txt
# Loaded 11940_3.txt
# Loaded 8647_4.txt
# Loaded 2848_4.txt
# Loaded 3231_1.txt
# Loaded 8653_2.txt
# Loaded 1197_3.txt
# Loaded 10449_2.txt
# Loaded 11009_1.txt
# Loaded 5876_1.txt
# Loaded 4050_3.txt
# Loaded 3561_4.txt
# Loaded 3580_4.txt
# Loaded 6621_4.txt
# Loaded 1138_1.txt
# Loaded 2956_4.txt
# Loaded 1972_4.txt
# Loaded 8365_1.txt
# Loaded 14_1.txt
# Loaded 6594_4.txt
# Loaded 8336_2.txt
# Loaded 2767_1.txt
# Loaded 5219_1.txt
# Loaded 10005_2.txt
# Loaded 1992_2.txt
# Loaded 8275_2.txt
# Loaded 1020_2.txt
# Loaded 6000_4.txt
# Loaded 8784_2.txt
# Loaded 3991_4.txt
# Loaded 9939_2.txt
# Loaded 4567_2.txt
# Loaded 7733_3.txt
# Loaded 8285_4.txt
# Loaded 3410_3.txt
# Loaded 4711_1.txt
# Loaded 3646_1.txt
# Loaded 399_1.txt
# Loaded 3798_2.txt
# Loaded 3254_1.txt
# Loaded 11800_1.txt
# Loaded 9092_3.txt
# Loaded 1978_2.txt
# Loaded 6889_4.txt
# Loaded 4995_1.txt
# Loaded 11047_1.txt
# Loaded 11454_3.txt
# Loaded 6461_2.txt
# Loaded 3338_2.txt
# Loaded 2202_4.txt
# Loaded 9766_3.txt
# Loaded 10905_1.txt
# Loaded 5571_1.txt
# Loaded 7161_4.txt
# Loaded 2733_3.txt
# Loaded 4138_2.txt
# Loaded 44_4.txt
# Loaded 7729_1.txt
# Loaded 6613_2.txt
# Loaded 10379_3.txt
# Loaded 2112_2.txt
# Loaded 5326_2.txt
# Loaded 5791_4.txt
# Loaded 9461_1.txt
# Loaded 9919_4.txt
# Loaded 6345_4.txt
# Loaded 5613_2.txt
# Loaded 4392_2.txt
# Loaded 9194_1.txt
# Loaded 7761_1.txt
# Loaded 3573_4.txt
# Loaded 4728_1.txt
# Loaded 3099_2.txt
# Loaded 5352_1.txt
# Loaded 11151_4.txt
# Loaded 7772_2.txt
# Loaded 11909_4.txt
# Loaded 1660_1.txt
# Loaded 1620_1.txt
# Loaded 8729_4.txt
# Loaded 9319_1.txt
# Loaded 9633_4.txt
# Loaded 9244_4.txt
# Loaded 312_4.txt
# Loaded 11226_1.txt
# Loaded 2823_1.txt
# Loaded 8383_1.txt
# Loaded 7263_2.txt
# Loaded 4428_2.txt
# Loaded 9403_1.txt
# Loaded 7874_1.txt
# Loaded 10261_1.txt
# Loaded 5773_3.txt
# Loaded 1151_1.txt
# Loaded 10942_1.txt
# Loaded 12315_1.txt
# Loaded 1710_1.txt
# Loaded 1825_4.txt
# Loaded 5506_4.txt
# Loaded 8843_4.txt
# Loaded 9906_1.txt
# Loaded 11254_4.txt
# Loaded 5687_1.txt
# Loaded 1797_3.txt
# Loaded 6539_2.txt
# Loaded 7583_4.txt
# Loaded 1549_1.txt
# Loaded 4503_1.txt
# Loaded 4928_1.txt
# Loaded 2265_4.txt
# Loaded 6474_1.txt
# Loaded 756_1.txt
# Loaded 11349_3.txt
# Loaded 1459_4.txt
# Loaded 2945_3.txt
# Loaded 7826_1.txt
# Loaded 9722_4.txt
# Loaded 7541_3.txt
# Loaded 7698_4.txt
# Loaded 9703_1.txt
# Loaded 8021_1.txt
# Loaded 2563_1.txt
# Loaded 3450_1.txt

# %%
len(reviews)
# Out:
# 50000

# %%
reviews[0]
# Out:
# "i'm not sure if it is available worldwide - but if anyone who's deciding what is supposed to be put on videotapes and distributed in video clubs - is reading this - please , please buy it! (if I wasn't clear: GET THE MOVIE INTO VIDEOSTORES!)<br /><br />can't be explained - must see!"

# %%
tokenized_corpus = []
for i in range(len(reviews)):
    tokenized_corpus.append(reviews[i].lower())
    tokenized_corpus[i] = tokenized_corpus[i].split()
    table = str.maketrans('', '', string.punctuation)
    tokenized_corpus[i] = [w.translate(table) for w in tokenized_corpus[i]]
    tokenized_corpus[i] = [word for word in tokenized_corpus[i] if word.isalpha()]
    tokenized_corpus[i] = [word for word in tokenized_corpus[i] if len(word) > 1]

# %%
tokenized_corpus[0]
# Out:
# ['im',
#  'not',
#  'sure',
#  'if',
#  'it',
#  'is',
#  'available',
#  'worldwide',
#  'but',
#  'if',
#  'anyone',
#  'whos',
#  'deciding',
#  'what',
#  'is',
#  'supposed',
#  'to',
#  'be',
#  'put',
#  'on',
#  'videotapes',
#  'and',
#  'distributed',
#  'in',
#  'video',
#  'clubs',
#  'is',
#  'reading',
#  'this',
#  'please',
#  'please',
#  'buy',
#  'it',
#  'if',
#  'wasnt',
#  'clear',
#  'get',
#  'the',
#  'movie',
#  'into',
#  'videostoresbr',
#  'br',
#  'cant',
#  'be',
#  'explained',
#  'must',
#  'see']

# %% [markdown]
# # word2vec

# %%
'''
Generating Vocabulary
'''

vocabulary = []
for sentence in tokenized_corpus:
    for token in sentence:
        if token not in vocabulary:
            vocabulary.append(token)

word2idx = {w: idx for (idx, w) in enumerate(vocabulary)}
idx2word = {idx: w for (idx, w) in enumerate(vocabulary)}

vocabulary_size = len(vocabulary)

# %%
word2idx = {w: idx for (idx, w) in enumerate(vocabulary)}
idx2word = {idx: w for (idx, w) in enumerate(vocabulary)}

vocabulary_size = len(vocabulary)

# %%
vocabulary_size
# Out:
# 175044

# %%
word2idx
# Out:
# {'im': 0,
#  'not': 1,
#  'sure': 2,
#  'if': 3,
#  'it': 4,
#  'is': 5,
#  'available': 6,
#  'worldwide': 7,
#  'but': 8,
#  'anyone': 9,
#  'whos': 10,
#  'deciding': 11,
#  'what': 12,
#  'supposed': 13,
#  'to': 14,
#  'be': 15,
#  'put': 16,
#  'on': 17,
#  'videotapes': 18,
#  'and': 19,
#  'distributed': 20,
#  'in': 21,
#  'video': 22,
#  'clubs': 23,
#  'reading': 24,
#  'this': 25,
#  'please': 26,
#  'buy': 27,
#  'wasnt': 28,
#  'clear': 29,
#  'get': 30,
#  'the': 31,
#  'movie': 32,
#  'into': 33,
#  'videostoresbr': 34,
#  'br': 35,
#  'cant': 36,
#  'explained': 37,
#  'must': 38,
#  'see': 39,
#  'no': 40,
#  'spoilers': 41,
#  'just': 42,
#  'plot': 43,
#  'details': 44,
#  'understand': 45,
#  'such': 46,
#  'hatred': 47,
#  'for': 48,
#  'episode': 49,
#  'you': 50,
#  'want': 51,
#  'watch': 52,
#  'bad': 53,
#  'of': 54,
#  'smallville': 55,
#  'subterranean': 56,
#  'now': 57,
#  'theres': 58,
#  'sack': 59,
#  'crap': 60,
#  'tom': 61,
#  'welling': 62,
#  'gives': 63,
#  'good': 64,
#  'performance': 65,
#  'dont': 66,
#  'say': 67,
#  'that': 68,
#  'very': 69,
#  'often': 70,
#  'michael': 71,
#  'rosenbaum': 72,
#  'great': 73,
#  'he': 74,
#  'most': 75,
#  'time': 76,
#  'alternate': 77,
#  'universe': 78,
#  'scenario': 79,
#  'seems': 80,
#  'eerily': 81,
#  'realistic': 82,
#  'martian': 83,
#  'manhunter': 84,
#  'who': 85,
#  'previously': 86,
#  'appeared': 87,
#  'static': 88,
#  'returns': 89,
#  'tells': 90,
#  'clark': 91,
#  'doctor': 92,
#  'head': 93,
#  'insane': 94,
#  'asylum': 95,
#  'where': 96,
#  'they': 97,
#  'are': 98,
#  'being': 99,
#  'held': 100,
#  'at': 101,
#  'actually': 102,
#  'phantom': 103,
#  'from': 104,
#  'zone': 105,
#  'wants': 106,
#  'return': 107,
#  'his': 108,
#  'kill': 109,
#  'him': 110,
#  'an': 111,
#  'overall': 112,
#  'with': 113,
#  'acting': 114,
#  'decent': 115,
#  'pace': 116,
#  'frustrating': 117,
#  'because': 118,
#  'one': 119,
#  'mans': 120,
#  'stubbornness': 121,
#  'leave': 122,
#  'native': 123,
#  'country': 124,
#  'dream': 125,
#  'land': 126,
#  'switzerland': 127,
#  'does': 128,
#  'achieve': 129,
#  'creates': 130,
#  'heartache': 131,
#  'all': 132,
#  'those': 133,
#  'involved': 134,
#  'along': 135,
#  'journey': 136,
#  'encounters': 137,
#  'scumbags': 138,
#  'take': 139,
#  'advantage': 140,
#  'other': 141,
#  'human': 142,
#  'suffering': 143,
#  'desperation': 144,
#  'wonderful': 145,
#  'writing': 146,
#  'directing': 147,
#  'fantastic': 148,
#  'witty': 149,
#  'clever': 150,
#  'script': 151,
#  'quality': 152,
#  'performances': 153,
#  'by': 154,
#  'actors': 155,
#  'ally': 156,
#  'sheedy': 157,
#  'strong': 158,
#  'dynamic': 159,
#  'delightfully': 160,
#  'quirky': 161,
#  'really': 162,
#  'original': 163,
#  'heartwarmingly': 164,
#  'unpredicatable': 165,
#  'scenes': 166,
#  'alive': 167,
#  'fresh': 168,
#  'energy': 169,
#  'talented': 170,
#  'production': 171,
#  'yes': 172,
#  'some': 173,
#  'people': 174,
#  'have': 175,
#  'said': 176,
#  'was': 177,
#  'waste': 178,
#  'money': 179,
#  'kind': 180,
#  'die': 181,
#  'hard': 182,
#  'dragonworldendingholy': 183,
#  'action': 184,
#  'fanbr': 185,
#  'my': 186,
#  'stand': 187,
#  'point': 188,
#  'had': 189,
#  'best': 190,
#  'sences': 191,
#  'were': 192,
#  'pretty': 193,
#  'dang': 194,
#  'its': 195,
#  'everything': 196,
#  'fell': 197,
#  'tougher': 198,
#  'right': 199,
#  'or': 200,
#  'about': 201,
#  'when': 202,
#  'evil': 203,
#  'trumph': 204,
#  'something': 205,
#  'save': 206,
#  'them': 207,
#  'though': 208,
#  'there': 209,
#  'funny': 210,
#  'lines': 211,
#  'gangs': 212,
#  'throughout': 213,
#  'which': 214,
#  'surprised': 215,
#  'mebr': 216,
#  'graphics': 217,
#  'damn': 218,
#  'mean': 219,
#  'effects': 220,
#  'big': 221,
#  'battle': 222,
#  'shown': 223,
#  'trailers': 224,
#  'live': 225,
#  'up': 226,
#  'whatever': 227,
#  'hype': 228,
#  'fight': 229,
#  'between': 230,
#  'end': 231,
#  'could': 232,
#  'been': 233,
#  'longer': 234,
#  'slightly': 235,
#  'better': 236,
#  'still': 237,
#  'goodbr': 238,
#  'parts': 239,
#  'think': 240,
#  'beginning': 241,
#  'showing': 242,
#  'lead': 243,
#  'battles': 244,
#  'go': 245,
#  'theaters': 246,
#  'then': 247,
#  'least': 248,
#  'dvderbr': 249,
#  'loved': 250,
#  'moviebut': 251,
#  'place': 252,
#  'fast': 253,
#  'fit': 254,
#  'well': 255,
#  'truth': 256,
#  'isnt': 257,
#  'so': 258,
#  'much': 259,
#  'as': 260,
#  'extended': 261,
#  'final': 262,
#  'followed': 263,
#  'tv': 264,
#  'series': 265,
#  'homicide': 266,
#  'life': 267,
#  'street': 268,
#  'suspect': 269,
#  'would': 270,
#  'following': 271,
#  'madefortv': 272,
#  'having': 273,
#  'says': 274,
#  'lot': 275,
#  'television': 276,
#  'every': 277,
#  'single': 278,
#  'cast': 279,
#  'member': 280,
#  'many': 281,
#  'after': 282,
#  'years': 283,
#  'absence': 284,
#  'once': 285,
#  'again': 286,
#  'portray': 287,
#  'their': 288,
#  'characters': 289,
#  'bring': 290,
#  'closure': 291,
#  'incredible': 292,
#  'program': 293,
#  'brings': 294,
#  'out': 295,
#  'sense': 296,
#  'family': 297,
#  'only': 298,
#  'amongst': 299,
#  'bittersweet': 300,
#  'knowing': 301,
#  'will': 302,
#  'last': 303,
#  'we': 304,
#  'together': 305,
#  'under': 306,
#  'title': 307,
#  'storywise': 308,
#  'found': 309,
#  'film': 310,
#  'somewhat': 311,
#  'lacking': 312,
#  'giardellos': 313,
#  'mayoral': 314,
#  'candidacy': 315,
#  'particularly': 316,
#  'contrived': 317,
#  'felt': 318,
#  'shooting': 319,
#  'couldve': 320,
#  'dealt': 321,
#  'within': 322,
#  'parameters': 323,
#  'regular': 324,
#  'position': 325,
#  'leiutenant': 326,
#  'also': 327,
#  'det': 328,
#  'baylisss': 329,
#  'extreme': 330,
#  'twist': 331,
#  'left': 332,
#  'hanging': 333,
#  'finally': 334,
#  'resolved': 335,
#  'never': 336,
#  'needed': 337,
#  'enjoyed': 338,
#  'mystery': 339,
#  'let': 340,
#  'us': 341,
#  'recall': 342,
#  'first': 343,
#  'episodes': 344,
#  'case': 345,
#  'went': 346,
#  'unsolved': 347,
#  'entire': 348,
#  'run': 349,
#  'devoted': 350,
#  'fan': 351,
#  'can': 352,
#  'love': 353,
#  'fact': 354,
#  'even': 355,
#  'got': 356,
#  'made': 357,
#  'hlots': 358,
#  'canceled': 359,
#  'recommend': 360,
#  'hasnt': 361,
#  'slightest': 362,
#  'exposure': 363,
#  'theyd': 364,
#  'release': 365,
#  'dvd': 366,
#  'entertaining': 367,
#  'saw': 368,
#  'girlfriend': 369,
#  'night': 370,
#  'use': 371,
#  'might': 372,
#  'eye': 373,
#  'routine': 374,
#  'combination': 375,
#  'comedy': 376,
#  'typical': 377,
#  'romance': 378,
#  'jim': 379,
#  'carey': 380,
#  'superb': 381,
#  'down': 382,
#  'luck': 383,
#  'reporter': 384,
#  'given': 385,
#  'power': 386,
#  'change': 387,
#  'himself': 388,
#  'city': 389,
#  'resides': 390,
#  'overly': 391,
#  'sappy': 392,
#  'flick': 393,
#  'wifebr': 394,
#  'am': 395,
#  'easy': 396,
#  'grader': 397,
#  'thats': 398,
#  'bigv': 399,
#  'over': 400,
#  'how': 401,
#  'both': 402,
#  'controversial': 403,
#  'gentle': 404,
#  'nearperfect': 405,
#  'structure': 406,
#  'daughters': 407,
#  'athletes': 408,
#  'apparently': 409,
#  'cultures': 410,
#  'smallbreasted': 411,
#  'either': 412,
#  'here': 413,
#  'bunch': 414,
#  'weve': 415,
#  'heard': 416,
#  'before': 417,
#  'folks': 418,
#  'different': 419,
#  'living': 420,
#  'fairly': 421,
#  'humdrum': 422,
#  'lives': 423,
#  'until': 424,
#  'female': 425,
#  'children': 426,
#  'potential': 427,
#  'become': 428,
#  'professional': 429,
#  'soccer': 430,
#  'players': 431,
#  'around': 432,
#  'parallelism': 433,
#  'two': 434,
#  'condescension': 435,
#  'seen': 436,
#  'modern': 437,
#  'valid': 438,
#  'silly': 439,
#  'too': 440,
#  'flaw': 441,
#  'hindu': 442,
#  'wedding': 443,
#  'ceremony': 444,
#  'seemed': 445,
#  'involve': 446,
#  'hundreds': 447,
#  'relatives': 448,
#  'child': 449,
#  'among': 450,
#  'wow': 451,
#  'absolutely': 452,
#  'brilliant': 453,
#  'know': 454,
#  'why': 455,
#  'everyone': 456,
#  'has': 457,
#  'slow': 458,
#  'thought': 459,
#  'perfect': 460,
#  'sullivan': 461,
#  'played': 462,
#  'hanks': 463,
#  'perfection': 464,
#  'sort': 465,
#  'hitman': 466,
#  'killer': 467,
#  'working': 468,
#  'john': 469,
#  'rooney': 470,
#  'paul': 471,
#  'newman': 472,
#  'disslikes': 473,
#  'job': 474,
#  'payed': 475,
#  'house': 476,
#  'helps': 477,
#  'financially': 478,
#  'nothing': 479,
#  'mr': 480,
#  'gave': 481,
#  'unaware': 482,
#  'witnesses': 483,
#  'cold': 484,
#  'blooded': 485,
#  'murder': 486,
#  'placed': 487,
#  'awkward': 488,
#  'atrocity': 489,
#  'occurs': 490,
#  'leaves': 491,
#  'son': 492,
#  'bent': 493,
#  'revenge': 494,
#  'rob': 495,
#  'abanks': 496,
#  'more': 497,
#  'build': 498,
#  'bond': 499,
#  'theyre': 500,
#  'team': 501,
#  'always': 502,
#  'jude': 503,
#  'law': 504,
#  'plays': 505,
#  'creepy': 506,
#  'role': 507,
#  'drama': 508,
#  'highly': 509,
#  'recommended': 510,
#  'shows': 511,
#  'beautiful': 512,
#  'story': 513,
#  'greatly': 514,
#  'disney': 515,
#  'flickit': 516,
#  'aging': 517,
#  'high': 518,
#  'school': 519,
#  'baseball': 520,
#  'coachdennis': 521,
#  'quaidwho': 522,
#  'way': 523,
#  'leagues': 524,
#  'pitcherbut': 525,
#  'suffered': 526,
#  'career': 527,
#  'ending': 528,
#  'injurybut': 529,
#  'through': 530,
#  'eventsjimmy': 531,
#  'morrisquaidgets': 532,
#  'try': 533,
#  'major': 534,
#  'league': 535,
#  'makes': 536,
#  'rosterthis': 537,
#  'filmit': 538,
#  'inspirationalbut': 539,
#  'doesnt': 540,
#  'pour': 541,
#  'thickits': 542,
#  'fun': 543,
#  'entertainingadults': 544,
#  'enjoy': 545,
#  'kidsit': 546,
#  'based': 547,
#  'upon': 548,
#  'true': 549,
#  'storythough': 550,
#  'filmmakers': 551,
#  'took': 552,
#  'liberties': 553,
#  'telling': 554,
#  'storyquaid': 555,
#  'sensational': 556,
#  'charactervery': 557,
#  'convincingif': 558,
#  'youre': 559,
#  'looking': 560,
#  'whole': 561,
#  'enjoylook': 562,
#  'imagine': 563,
#  'victorian': 564,
#  'literature': 565,
#  'slowly': 566,
#  'sinking': 567,
#  'mire': 568,
#  'increasingly': 569,
#  'distant': 570,
#  'past': 571,
#  'pulled': 572,
#  'weight': 573,
#  'underskirts': 574,
#  'comes': 575,
#  'redemptive': 576,
#  'dramatisations': 577,
#  'like': 578,
#  'bbc': 579,
#  'produce': 580,
#  'finely': 581,
#  'gets': 582,
#  'new': 583,
#  'stab': 584,
#  'religious': 585,
#  'themes': 586,
#  'moral': 587,
#  'overtones': 588,
#  'may': 589,
#  'ill': 590,
#  'ease': 591,
#  'world': 592,
#  'easily': 593,
#  'shocked': 594,
#  'acquainted': 595,
#  'cohabitation': 596,
#  'affairs': 597,
#  'domestic': 598,
#  'violence': 599,
#  'old': 600,
#  'welltold': 601,
#  'stories': 602,
#  'enduring': 603,
#  'ones': 604,
#  'hidden': 605,
#  'gembr': 606,
#  'gauge': 607,
#  'today': 608,
#  'forceful': 609,
#  'feminist': 610,
#  'extraordinary': 611,
#  'ann': 612,
#  'brontes': 613,
#  'masterpiece': 614,
#  'tenant': 615,
#  'wildfell': 616,
#  'hall': 617,
#  'emerging': 618,
#  'primeval': 619,
#  'slime': 620,
#  'restrictive': 621,
#  'corsets': 622,
#  'bodily': 623,
#  'mental': 624,
#  'societal': 625,
#  'her': 626,
#  'heroine': 627,
#  'helen': 628,
#  'huntingdon': 629,
#  'escapes': 630,
#  'miserable': 631,
#  'marriage': 632,
#  'flees': 633,
#  'brutality': 634,
#  'alcoholism': 635,
#  'braves': 636,
#  'abusive': 637,
#  'husbands': 638,
#  'fury': 639,
#  'societys': 640,
#  'pinched': 641,
#  'intolerance': 642,
#  'malicious': 643,
#  'gossip': 644,
#  'wreak': 645,
#  'she': 646,
#  'pays': 647,
#  'price': 648,
#  'retains': 649,
#  'selfrespect': 650,
#  'falls': 651,
#  'emerges': 652,
#  'battered': 653,
#  'victorious': 654,
#  'watching': 655,
#  'women': 656,
#  'these': 657,
#  'screenbr': 658,
#  'brits': 659,
#  'offer': 660,
#  'beautifully': 661,
#  'handled': 662,
#  'real': 663,
#  'passion': 664,
#  'feeling': 665,
#  'wellmatched': 666,
#  'tara': 667,
#  'fitzgerald': 668,
#  'inhabits': 669,
#  'aspect': 670,
#  'complicated': 671,
#  'reviewers': 672,
#  'less': 673,
#  'sharply': 674,
#  'defined': 675,
#  'face': 676,
#  'survive': 677,
#  'petrifying': 678,
#  'hairstyle': 679,
#  'toby': 680,
#  'stephens': 681,
#  'striking': 682,
#  'sparks': 683,
#  'off': 684,
#  'contributes': 685,
#  'headstrong': 686,
#  'handsome': 687,
#  'youth': 688,
#  'passionate': 689,
#  'yearning': 690,
#  'vulnerability': 691,
#  'rupert': 692,
#  'graves': 693,
#  'favourite': 694,
#  'british': 695,
#  'ever': 696,
#  'enjoys': 697,
#  'charismatic': 698,
#  'villain': 699,
#  'almost': 700,
#  'supporting': 701,
#  'ably': 702,
#  'create': 703,
#  'sink': 704,
#  'without': 705,
#  'coarse': 706,
#  'compromises': 707,
#  'tastes': 708,
#  'preached': 709,
#  'another': 710,
#  'classic': 711,
#  'romantic': 712,
#  'should': 713,
#  'dramatised': 714,
#  'soylent': 715,
#  'green': 716,
#  'waiting': 717,
#  'someone': 718,
#  'redo': 719,
#  'itthey': 720,
#  'seem': 721,
#  'remaking': 722,
#  'scifi': 723,
#  'classics': 724,
#  'days': 725,
#  'ie': 726,
#  'war': 727,
#  'worldsand': 728,
#  'hoping': 729,
#  'directorproducer': 730,
#  'todays': 731,
#  'computer': 732,
#  'animation': 733,
#  'technology': 734,
#  'picture': 735,
#  'antiutopian': 736,
#  'films': 737,
#  'farfetched': 738,
#  'race': 739,
#  'breeds': 740,
#  'roaches': 741,
#  'outside': 742,
#  'influence': 743,
#  'curtail': 744,
#  'humans': 745,
#  'option': 746,
#  'putting': 747,
#  'kibosh': 748,
#  'procreation': 749,
#  'lesser': 750,
#  'species': 751,
#  'hand': 752,
#  'control': 753,
#  'breeding': 754,
#  'except': 755,
#  'ourselves': 756,
#  'despite': 757,
#  'diseases': 758,
#  'wars': 759,
#  'abortions': 760,
#  'birth': 761,
#  'etc': 762,
#  'multiplies': 763,
#  'bacteria': 764,
#  'petri': 765,
#  'dish': 766,
#  'malthusian': 767,
#  'economics': 768,
#  'states': 769,
#  'any': 770,
#  'including': 771,
#  'multiply': 772,
#  'beyond': 773,
#  'means': 774,
#  'subsistence': 775,
#  'billion': 776,
#  'growingthats': 777,
#  'obscene': 778,
#  'alright': 779,
#  'representation': 780,
#  'several': 781,
#  'things': 782,
#  'starters': 783,
#  'disgruntled': 784,
#  'student': 785,
#  'gun': 786,
#  'shoots': 787,
#  'roughly': 788,
#  'students': 789,
#  'survives': 790,
#  'hospital': 791,
#  'extensive': 792,
#  'injuries': 793,
#  'character': 794,
#  'consider': 795,
#  'lonergoth': 796,
#  'movies': 797,
#  'stating': 798,
#  'quite': 799,
#  'mysterious': 800,
#  'unharmed': 801,
#  'victimized': 802,
#  'classroom': 803,
#  'shes': 804,
#  'questioned': 805,
#  'due': 806,
#  'history': 807,
#  'shooter': 808,
#  'record': 809,
#  'phone': 810,
#  'anyhow': 811,
#  'brief': 812,
#  'person': 813,
#  'despise': 814,
#  'society': 815,
#  'yet': 816,
#  'unexplained': 817,
#  'events': 818,
#  'spent': 819,
#  'year': 820,
#  'failing': 821,
#  'grade': 822,
#  'desire': 823,
#  'graduate': 824,
#  'principle': 825,
#  'practically': 826,
#  'cons': 827,
#  'possible': 828,
#  'pass': 829,
#  'spend': 830,
#  'survivor': 831,
#  'girl': 832,
#  'hospitalbr': 833,
#  'leads': 834,
#  'nearly': 835,
#  'entirely': 836,
#  'opposite': 837,
#  'social': 838,
#  'level': 839,
#  'while': 840,
#  'alisha': 841,
#  'quiet': 842,
#  'inwardly': 843,
#  'disturbed': 844,
#  'antisocial': 845,
#  'goth': 846,
#  'spends': 847,
#  'alone': 848,
#  'read': 849,
#  'closetout': 850,
#  'closet': 851,
#  'bookworm': 852,
#  'rich': 853,
#  'popular': 854,
#  'bubbly': 855,
#  'incredibly': 856,
#  'optimistic': 857,
#  'trapped': 858,
#  'own': 859,
#  'fantasy': 860,
#  'ignoring': 861,
#  'realism': 862,
#  'feel': 863,
#  'roles': 864,
#  'marvelous': 865,
#  'representing': 866,
#  'cliques': 867,
#  'highschool': 868,
#  'importantly': 869,
#  'girls': 870,
#  'each': 871,
#  'eventually': 872,
#  'open': 873,
#  'injured': 874,
#  'learns': 875,
#  'deep': 876,
#  'meaningful': 877,
#  'sheltered': 878,
#  'complete': 879,
#  'abandonment': 880,
#  'locking': 881,
#  'inside': 882,
#  'thingbr': 883,
#  'look': 884,
#  'connection': 885,
#  'snobby': 886,
#  'hateful': 887,
#  'rest': 888,
#  'suffer': 889,
#  'taking': 890,
#  'innocent': 891,
#  'seemingly': 892,
#  'fantasized': 893,
#  'meets': 894,
#  'outcast': 895,
#  'judge': 896,
#  'perhaps': 897,
#  'intelligent': 898,
#  'known': 899,
#  'words': 900,
#  'focus': 901,
#  'teaching': 902,
#  'lesson': 903,
#  'thatbr': 904,
#  'stated': 905,
#  'representative': 906,
#  'deal': 907,
#  'large': 908,
#  'lifechanging': 909,
#  'catastrophe': 910,
#  'truly': 911,
#  'symbolic': 912,
#  'instead': 913,
#  'straight': 914,
#  'forward': 915,
#  'message': 916,
#  'long': 917,
#  'arent': 918,
#  'afraid': 919,
#  'your': 920,
#  'mind': 921,
#  'heart': 922,
#  'emotions': 923,
#  'familiar': 924,
#  'portrayed': 925,
#  'miraculouslybr': 926,
#  'ive': 927,
#  'storyline': 928,
#  'emotion': 929,
#  'flowing': 930,
#  'relating': 931,
#  'possibly': 932,
#  'crying': 933,
#  'far': 934,
#  'heartwrenching': 935,
#  'impactful': 936,
#  'believed': 937,
#  'alter': 938,
#  'persons': 939,
#  'changed': 940,
#  'minebr': 941,
#  'adored': 942,
#  'moving': 943,
#  'amazing': 944,
#  'indie': 945,
#  'recent': 946,
#  'day': 947,
#  'super': 948,
#  'small': 949,
#  'budget': 950,
#  'special': 951,
#  'blow': 952,
#  'away': 953,
#  'alot': 954,
#  'current': 955,
#  'chance': 956,
#  'dragged': 957,
#  'immediately': 958,
#  'audience': 959,
#  'consisted': 960,
#  'mainly': 961,
#  'elderly': 962,
#  'however': 963,
#  'utterly': 964,
#  'fascinating': 965,
#  'targeted': 966,
#  'towards': 967,
#  'believable': 968,
#  'myself': 969,
#  'discussing': 970,
#  'hours': 971,
#  'afterwards': 972,
#  'few': 973,
#  'engrossing': 974,
#  'necessary': 975,
#  'help': 976,
#  'situation': 977,
#  'valuable': 978,
#  'mainstream': 979,
#  'cannot': 980,
#  'prefer': 981,
#  'thrilling': 982,
#  'interesting': 983,
#  'experience': 984,
#  'finished': 985,
#  'min': 986,
#  'version': 987,
#  'widescreen': 988,
#  'friends': 989,
#  'blown': 990,
#  'wont': 991,
#  'bother': 992,
#  'repeating': 993,
#  'others': 994,
#  'do': 995,
#  'concept': 996,
#  'unexpected': 997,
#  'huge': 998,
#  'exhausting': 999,
#  ...}

# %%
idx2word
# Out:
# {0: 'im',
#  1: 'not',
#  2: 'sure',
#  3: 'if',
#  4: 'it',
#  5: 'is',
#  6: 'available',
#  7: 'worldwide',
#  8: 'but',
#  9: 'anyone',
#  10: 'whos',
#  11: 'deciding',
#  12: 'what',
#  13: 'supposed',
#  14: 'to',
#  15: 'be',
#  16: 'put',
#  17: 'on',
#  18: 'videotapes',
#  19: 'and',
#  20: 'distributed',
#  21: 'in',
#  22: 'video',
#  23: 'clubs',
#  24: 'reading',
#  25: 'this',
#  26: 'please',
#  27: 'buy',
#  28: 'wasnt',
#  29: 'clear',
#  30: 'get',
#  31: 'the',
#  32: 'movie',
#  33: 'into',
#  34: 'videostoresbr',
#  35: 'br',
#  36: 'cant',
#  37: 'explained',
#  38: 'must',
#  39: 'see',
#  40: 'no',
#  41: 'spoilers',
#  42: 'just',
#  43: 'plot',
#  44: 'details',
#  45: 'understand',
#  46: 'such',
#  47: 'hatred',
#  48: 'for',
#  49: 'episode',
#  50: 'you',
#  51: 'want',
#  52: 'watch',
#  53: 'bad',
#  54: 'of',
#  55: 'smallville',
#  56: 'subterranean',
#  57: 'now',
#  58: 'theres',
#  59: 'sack',
#  60: 'crap',
#  61: 'tom',
#  62: 'welling',
#  63: 'gives',
#  64: 'good',
#  65: 'performance',
#  66: 'dont',
#  67: 'say',
#  68: 'that',
#  69: 'very',
#  70: 'often',
#  71: 'michael',
#  72: 'rosenbaum',
#  73: 'great',
#  74: 'he',
#  75: 'most',
#  76: 'time',
#  77: 'alternate',
#  78: 'universe',
#  79: 'scenario',
#  80: 'seems',
#  81: 'eerily',
#  82: 'realistic',
#  83: 'martian',
#  84: 'manhunter',
#  85: 'who',
#  86: 'previously',
#  87: 'appeared',
#  88: 'static',
#  89: 'returns',
#  90: 'tells',
#  91: 'clark',
#  92: 'doctor',
#  93: 'head',
#  94: 'insane',
#  95: 'asylum',
#  96: 'where',
#  97: 'they',
#  98: 'are',
#  99: 'being',
#  100: 'held',
#  101: 'at',
#  102: 'actually',
#  103: 'phantom',
#  104: 'from',
#  105: 'zone',
#  106: 'wants',
#  107: 'return',
#  108: 'his',
#  109: 'kill',
#  110: 'him',
#  111: 'an',
#  112: 'overall',
#  113: 'with',
#  114: 'acting',
#  115: 'decent',
#  116: 'pace',
#  117: 'frustrating',
#  118: 'because',
#  119: 'one',
#  120: 'mans',
#  121: 'stubbornness',
#  122: 'leave',
#  123: 'native',
#  124: 'country',
#  125: 'dream',
#  126: 'land',
#  127: 'switzerland',
#  128: 'does',
#  129: 'achieve',
#  130: 'creates',
#  131: 'heartache',
#  132: 'all',
#  133: 'those',
#  134: 'involved',
#  135: 'along',
#  136: 'journey',
#  137: 'encounters',
#  138: 'scumbags',
#  139: 'take',
#  140: 'advantage',
#  141: 'other',
#  142: 'human',
#  143: 'suffering',
#  144: 'desperation',
#  145: 'wonderful',
#  146: 'writing',
#  147: 'directing',
#  148: 'fantastic',
#  149: 'witty',
#  150: 'clever',
#  151: 'script',
#  152: 'quality',
#  153: 'performances',
#  154: 'by',
#  155: 'actors',
#  156: 'ally',
#  157: 'sheedy',
#  158: 'strong',
#  159: 'dynamic',
#  160: 'delightfully',
#  161: 'quirky',
#  162: 'really',
#  163: 'original',
#  164: 'heartwarmingly',
#  165: 'unpredicatable',
#  166: 'scenes',
#  167: 'alive',
#  168: 'fresh',
#  169: 'energy',
#  170: 'talented',
#  171: 'production',
#  172: 'yes',
#  173: 'some',
#  174: 'people',
#  175: 'have',
#  176: 'said',
#  177: 'was',
#  178: 'waste',
#  179: 'money',
#  180: 'kind',
#  181: 'die',
#  182: 'hard',
#  183: 'dragonworldendingholy',
#  184: 'action',
#  185: 'fanbr',
#  186: 'my',
#  187: 'stand',
#  188: 'point',
#  189: 'had',
#  190: 'best',
#  191: 'sences',
#  192: 'were',
#  193: 'pretty',
#  194: 'dang',
#  195: 'its',
#  196: 'everything',
#  197: 'fell',
#  198: 'tougher',
#  199: 'right',
#  200: 'or',
#  201: 'about',
#  202: 'when',
#  203: 'evil',
#  204: 'trumph',
#  205: 'something',
#  206: 'save',
#  207: 'them',
#  208: 'though',
#  209: 'there',
#  210: 'funny',
#  211: 'lines',
#  212: 'gangs',
#  213: 'throughout',
#  214: 'which',
#  215: 'surprised',
#  216: 'mebr',
#  217: 'graphics',
#  218: 'damn',
#  219: 'mean',
#  220: 'effects',
#  221: 'big',
#  222: 'battle',
#  223: 'shown',
#  224: 'trailers',
#  225: 'live',
#  226: 'up',
#  227: 'whatever',
#  228: 'hype',
#  229: 'fight',
#  230: 'between',
#  231: 'end',
#  232: 'could',
#  233: 'been',
#  234: 'longer',
#  235: 'slightly',
#  236: 'better',
#  237: 'still',
#  238: 'goodbr',
#  239: 'parts',
#  240: 'think',
#  241: 'beginning',
#  242: 'showing',
#  243: 'lead',
#  244: 'battles',
#  245: 'go',
#  246: 'theaters',
#  247: 'then',
#  248: 'least',
#  249: 'dvderbr',
#  250: 'loved',
#  251: 'moviebut',
#  252: 'place',
#  253: 'fast',
#  254: 'fit',
#  255: 'well',
#  256: 'truth',
#  257: 'isnt',
#  258: 'so',
#  259: 'much',
#  260: 'as',
#  261: 'extended',
#  262: 'final',
#  263: 'followed',
#  264: 'tv',
#  265: 'series',
#  266: 'homicide',
#  267: 'life',
#  268: 'street',
#  269: 'suspect',
#  270: 'would',
#  271: 'following',
#  272: 'madefortv',
#  273: 'having',
#  274: 'says',
#  275: 'lot',
#  276: 'television',
#  277: 'every',
#  278: 'single',
#  279: 'cast',
#  280: 'member',
#  281: 'many',
#  282: 'after',
#  283: 'years',
#  284: 'absence',
#  285: 'once',
#  286: 'again',
#  287: 'portray',
#  288: 'their',
#  289: 'characters',
#  290: 'bring',
#  291: 'closure',
#  292: 'incredible',
#  293: 'program',
#  294: 'brings',
#  295: 'out',
#  296: 'sense',
#  297: 'family',
#  298: 'only',
#  299: 'amongst',
#  300: 'bittersweet',
#  301: 'knowing',
#  302: 'will',
#  303: 'last',
#  304: 'we',
#  305: 'together',
#  306: 'under',
#  307: 'title',
#  308: 'storywise',
#  309: 'found',
#  310: 'film',
#  311: 'somewhat',
#  312: 'lacking',
#  313: 'giardellos',
#  314: 'mayoral',
#  315: 'candidacy',
#  316: 'particularly',
#  317: 'contrived',
#  318: 'felt',
#  319: 'shooting',
#  320: 'couldve',
#  321: 'dealt',
#  322: 'within',
#  323: 'parameters',
#  324: 'regular',
#  325: 'position',
#  326: 'leiutenant',
#  327: 'also',
#  328: 'det',
#  329: 'baylisss',
#  330: 'extreme',
#  331: 'twist',
#  332: 'left',
#  333: 'hanging',
#  334: 'finally',
#  335: 'resolved',
#  336: 'never',
#  337: 'needed',
#  338: 'enjoyed',
#  339: 'mystery',
#  340: 'let',
#  341: 'us',
#  342: 'recall',
#  343: 'first',
#  344: 'episodes',
#  345: 'case',
#  346: 'went',
#  347: 'unsolved',
#  348: 'entire',
#  349: 'run',
#  350: 'devoted',
#  351: 'fan',
#  352: 'can',
#  353: 'love',
#  354: 'fact',
#  355: 'even',
#  356: 'got',
#  357: 'made',
#  358: 'hlots',
#  359: 'canceled',
#  360: 'recommend',
#  361: 'hasnt',
#  362: 'slightest',
#  363: 'exposure',
#  364: 'theyd',
#  365: 'release',
#  366: 'dvd',
#  367: 'entertaining',
#  368: 'saw',
#  369: 'girlfriend',
#  370: 'night',
#  371: 'use',
#  372: 'might',
#  373: 'eye',
#  374: 'routine',
#  375: 'combination',
#  376: 'comedy',
#  377: 'typical',
#  378: 'romance',
#  379: 'jim',
#  380: 'carey',
#  381: 'superb',
#  382: 'down',
#  383: 'luck',
#  384: 'reporter',
#  385: 'given',
#  386: 'power',
#  387: 'change',
#  388: 'himself',
#  389: 'city',
#  390: 'resides',
#  391: 'overly',
#  392: 'sappy',
#  393: 'flick',
#  394: 'wifebr',
#  395: 'am',
#  396: 'easy',
#  397: 'grader',
#  398: 'thats',
#  399: 'bigv',
#  400: 'over',
#  401: 'how',
#  402: 'both',
#  403: 'controversial',
#  404: 'gentle',
#  405: 'nearperfect',
#  406: 'structure',
#  407: 'daughters',
#  408: 'athletes',
#  409: 'apparently',
#  410: 'cultures',
#  411: 'smallbreasted',
#  412: 'either',
#  413: 'here',
#  414: 'bunch',
#  415: 'weve',
#  416: 'heard',
#  417: 'before',
#  418: 'folks',
#  419: 'different',
#  420: 'living',
#  421: 'fairly',
#  422: 'humdrum',
#  423: 'lives',
#  424: 'until',
#  425: 'female',
#  426: 'children',
#  427: 'potential',
#  428: 'become',
#  429: 'professional',
#  430: 'soccer',
#  431: 'players',
#  432: 'around',
#  433: 'parallelism',
#  434: 'two',
#  435: 'condescension',
#  436: 'seen',
#  437: 'modern',
#  438: 'valid',
#  439: 'silly',
#  440: 'too',
#  441: 'flaw',
#  442: 'hindu',
#  443: 'wedding',
#  444: 'ceremony',
#  445: 'seemed',
#  446: 'involve',
#  447: 'hundreds',
#  448: 'relatives',
#  449: 'child',
#  450: 'among',
#  451: 'wow',
#  452: 'absolutely',
#  453: 'brilliant',
#  454: 'know',
#  455: 'why',
#  456: 'everyone',
#  457: 'has',
#  458: 'slow',
#  459: 'thought',
#  460: 'perfect',
#  461: 'sullivan',
#  462: 'played',
#  463: 'hanks',
#  464: 'perfection',
#  465: 'sort',
#  466: 'hitman',
#  467: 'killer',
#  468: 'working',
#  469: 'john',
#  470: 'rooney',
#  471: 'paul',
#  472: 'newman',
#  473: 'disslikes',
#  474: 'job',
#  475: 'payed',
#  476: 'house',
#  477: 'helps',
#  478: 'financially',
#  479: 'nothing',
#  480: 'mr',
#  481: 'gave',
#  482: 'unaware',
#  483: 'witnesses',
#  484: 'cold',
#  485: 'blooded',
#  486: 'murder',
#  487: 'placed',
#  488: 'awkward',
#  489: 'atrocity',
#  490: 'occurs',
#  491: 'leaves',
#  492: 'son',
#  493: 'bent',
#  494: 'revenge',
#  495: 'rob',
#  496: 'abanks',
#  497: 'more',
#  498: 'build',
#  499: 'bond',
#  500: 'theyre',
#  501: 'team',
#  502: 'always',
#  503: 'jude',
#  504: 'law',
#  505: 'plays',
#  506: 'creepy',
#  507: 'role',
#  508: 'drama',
#  509: 'highly',
#  510: 'recommended',
#  511: 'shows',
#  512: 'beautiful',
#  513: 'story',
#  514: 'greatly',
#  515: 'disney',
#  516: 'flickit',
#  517: 'aging',
#  518: 'high',
#  519: 'school',
#  520: 'baseball',
#  521: 'coachdennis',
#  522: 'quaidwho',
#  523: 'way',
#  524: 'leagues',
#  525: 'pitcherbut',
#  526: 'suffered',
#  527: 'career',
#  528: 'ending',
#  529: 'injurybut',
#  530: 'through',
#  531: 'eventsjimmy',
#  532: 'morrisquaidgets',
#  533: 'try',
#  534: 'major',
#  535: 'league',
#  536: 'makes',
#  537: 'rosterthis',
#  538: 'filmit',
#  539: 'inspirationalbut',
#  540: 'doesnt',
#  541: 'pour',
#  542: 'thickits',
#  543: 'fun',
#  544: 'entertainingadults',
#  545: 'enjoy',
#  546: 'kidsit',
#  547: 'based',
#  548: 'upon',
#  549: 'true',
#  550: 'storythough',
#  551: 'filmmakers',
#  552: 'took',
#  553: 'liberties',
#  554: 'telling',
#  555: 'storyquaid',
#  556: 'sensational',
#  557: 'charactervery',
#  558: 'convincingif',
#  559: 'youre',
#  560: 'looking',
#  561: 'whole',
#  562: 'enjoylook',
#  563: 'imagine',
#  564: 'victorian',
#  565: 'literature',
#  566: 'slowly',
#  567: 'sinking',
#  568: 'mire',
#  569: 'increasingly',
#  570: 'distant',
#  571: 'past',
#  572: 'pulled',
#  573: 'weight',
#  574: 'underskirts',
#  575: 'comes',
#  576: 'redemptive',
#  577: 'dramatisations',
#  578: 'like',
#  579: 'bbc',
#  580: 'produce',
#  581: 'finely',
#  582: 'gets',
#  583: 'new',
#  584: 'stab',
#  585: 'religious',
#  586: 'themes',
#  587: 'moral',
#  588: 'overtones',
#  589: 'may',
#  590: 'ill',
#  591: 'ease',
#  592: 'world',
#  593: 'easily',
#  594: 'shocked',
#  595: 'acquainted',
#  596: 'cohabitation',
#  597: 'affairs',
#  598: 'domestic',
#  599: 'violence',
#  600: 'old',
#  601: 'welltold',
#  602: 'stories',
#  603: 'enduring',
#  604: 'ones',
#  605: 'hidden',
#  606: 'gembr',
#  607: 'gauge',
#  608: 'today',
#  609: 'forceful',
#  610: 'feminist',
#  611: 'extraordinary',
#  612: 'ann',
#  613: 'brontes',
#  614: 'masterpiece',
#  615: 'tenant',
#  616: 'wildfell',
#  617: 'hall',
#  618: 'emerging',
#  619: 'primeval',
#  620: 'slime',
#  621: 'restrictive',
#  622: 'corsets',
#  623: 'bodily',
#  624: 'mental',
#  625: 'societal',
#  626: 'her',
#  627: 'heroine',
#  628: 'helen',
#  629: 'huntingdon',
#  630: 'escapes',
#  631: 'miserable',
#  632: 'marriage',
#  633: 'flees',
#  634: 'brutality',
#  635: 'alcoholism',
#  636: 'braves',
#  637: 'abusive',
#  638: 'husbands',
#  639: 'fury',
#  640: 'societys',
#  641: 'pinched',
#  642: 'intolerance',
#  643: 'malicious',
#  644: 'gossip',
#  645: 'wreak',
#  646: 'she',
#  647: 'pays',
#  648: 'price',
#  649: 'retains',
#  650: 'selfrespect',
#  651: 'falls',
#  652: 'emerges',
#  653: 'battered',
#  654: 'victorious',
#  655: 'watching',
#  656: 'women',
#  657: 'these',
#  658: 'screenbr',
#  659: 'brits',
#  660: 'offer',
#  661: 'beautifully',
#  662: 'handled',
#  663: 'real',
#  664: 'passion',
#  665: 'feeling',
#  666: 'wellmatched',
#  667: 'tara',
#  668: 'fitzgerald',
#  669: 'inhabits',
#  670: 'aspect',
#  671: 'complicated',
#  672: 'reviewers',
#  673: 'less',
#  674: 'sharply',
#  675: 'defined',
#  676: 'face',
#  677: 'survive',
#  678: 'petrifying',
#  679: 'hairstyle',
#  680: 'toby',
#  681: 'stephens',
#  682: 'striking',
#  683: 'sparks',
#  684: 'off',
#  685: 'contributes',
#  686: 'headstrong',
#  687: 'handsome',
#  688: 'youth',
#  689: 'passionate',
#  690: 'yearning',
#  691: 'vulnerability',
#  692: 'rupert',
#  693: 'graves',
#  694: 'favourite',
#  695: 'british',
#  696: 'ever',
#  697: 'enjoys',
#  698: 'charismatic',
#  699: 'villain',
#  700: 'almost',
#  701: 'supporting',
#  702: 'ably',
#  703: 'create',
#  704: 'sink',
#  705: 'without',
#  706: 'coarse',
#  707: 'compromises',
#  708: 'tastes',
#  709: 'preached',
#  710: 'another',
#  711: 'classic',
#  712: 'romantic',
#  713: 'should',
#  714: 'dramatised',
#  715: 'soylent',
#  716: 'green',
#  717: 'waiting',
#  718: 'someone',
#  719: 'redo',
#  720: 'itthey',
#  721: 'seem',
#  722: 'remaking',
#  723: 'scifi',
#  724: 'classics',
#  725: 'days',
#  726: 'ie',
#  727: 'war',
#  728: 'worldsand',
#  729: 'hoping',
#  730: 'directorproducer',
#  731: 'todays',
#  732: 'computer',
#  733: 'animation',
#  734: 'technology',
#  735: 'picture',
#  736: 'antiutopian',
#  737: 'films',
#  738: 'farfetched',
#  739: 'race',
#  740: 'breeds',
#  741: 'roaches',
#  742: 'outside',
#  743: 'influence',
#  744: 'curtail',
#  745: 'humans',
#  746: 'option',
#  747: 'putting',
#  748: 'kibosh',
#  749: 'procreation',
#  750: 'lesser',
#  751: 'species',
#  752: 'hand',
#  753: 'control',
#  754: 'breeding',
#  755: 'except',
#  756: 'ourselves',
#  757: 'despite',
#  758: 'diseases',
#  759: 'wars',
#  760: 'abortions',
#  761: 'birth',
#  762: 'etc',
#  763: 'multiplies',
#  764: 'bacteria',
#  765: 'petri',
#  766: 'dish',
#  767: 'malthusian',
#  768: 'economics',
#  769: 'states',
#  770: 'any',
#  771: 'including',
#  772: 'multiply',
#  773: 'beyond',
#  774: 'means',
#  775: 'subsistence',
#  776: 'billion',
#  777: 'growingthats',
#  778: 'obscene',
#  779: 'alright',
#  780: 'representation',
#  781: 'several',
#  782: 'things',
#  783: 'starters',
#  784: 'disgruntled',
#  785: 'student',
#  786: 'gun',
#  787: 'shoots',
#  788: 'roughly',
#  789: 'students',
#  790: 'survives',
#  791: 'hospital',
#  792: 'extensive',
#  793: 'injuries',
#  794: 'character',
#  795: 'consider',
#  796: 'lonergoth',
#  797: 'movies',
#  798: 'stating',
#  799: 'quite',
#  800: 'mysterious',
#  801: 'unharmed',
#  802: 'victimized',
#  803: 'classroom',
#  804: 'shes',
#  805: 'questioned',
#  806: 'due',
#  807: 'history',
#  808: 'shooter',
#  809: 'record',
#  810: 'phone',
#  811: 'anyhow',
#  812: 'brief',
#  813: 'person',
#  814: 'despise',
#  815: 'society',
#  816: 'yet',
#  817: 'unexplained',
#  818: 'events',
#  819: 'spent',
#  820: 'year',
#  821: 'failing',
#  822: 'grade',
#  823: 'desire',
#  824: 'graduate',
#  825: 'principle',
#  826: 'practically',
#  827: 'cons',
#  828: 'possible',
#  829: 'pass',
#  830: 'spend',
#  831: 'survivor',
#  832: 'girl',
#  833: 'hospitalbr',
#  834: 'leads',
#  835: 'nearly',
#  836: 'entirely',
#  837: 'opposite',
#  838: 'social',
#  839: 'level',
#  840: 'while',
#  841: 'alisha',
#  842: 'quiet',
#  843: 'inwardly',
#  844: 'disturbed',
#  845: 'antisocial',
#  846: 'goth',
#  847: 'spends',
#  848: 'alone',
#  849: 'read',
#  850: 'closetout',
#  851: 'closet',
#  852: 'bookworm',
#  853: 'rich',
#  854: 'popular',
#  855: 'bubbly',
#  856: 'incredibly',
#  857: 'optimistic',
#  858: 'trapped',
#  859: 'own',
#  860: 'fantasy',
#  861: 'ignoring',
#  862: 'realism',
#  863: 'feel',
#  864: 'roles',
#  865: 'marvelous',
#  866: 'representing',
#  867: 'cliques',
#  868: 'highschool',
#  869: 'importantly',
#  870: 'girls',
#  871: 'each',
#  872: 'eventually',
#  873: 'open',
#  874: 'injured',
#  875: 'learns',
#  876: 'deep',
#  877: 'meaningful',
#  878: 'sheltered',
#  879: 'complete',
#  880: 'abandonment',
#  881: 'locking',
#  882: 'inside',
#  883: 'thingbr',
#  884: 'look',
#  885: 'connection',
#  886: 'snobby',
#  887: 'hateful',
#  888: 'rest',
#  889: 'suffer',
#  890: 'taking',
#  891: 'innocent',
#  892: 'seemingly',
#  893: 'fantasized',
#  894: 'meets',
#  895: 'outcast',
#  896: 'judge',
#  897: 'perhaps',
#  898: 'intelligent',
#  899: 'known',
#  900: 'words',
#  901: 'focus',
#  902: 'teaching',
#  903: 'lesson',
#  904: 'thatbr',
#  905: 'stated',
#  906: 'representative',
#  907: 'deal',
#  908: 'large',
#  909: 'lifechanging',
#  910: 'catastrophe',
#  911: 'truly',
#  912: 'symbolic',
#  913: 'instead',
#  914: 'straight',
#  915: 'forward',
#  916: 'message',
#  917: 'long',
#  918: 'arent',
#  919: 'afraid',
#  920: 'your',
#  921: 'mind',
#  922: 'heart',
#  923: 'emotions',
#  924: 'familiar',
#  925: 'portrayed',
#  926: 'miraculouslybr',
#  927: 'ive',
#  928: 'storyline',
#  929: 'emotion',
#  930: 'flowing',
#  931: 'relating',
#  932: 'possibly',
#  933: 'crying',
#  934: 'far',
#  935: 'heartwrenching',
#  936: 'impactful',
#  937: 'believed',
#  938: 'alter',
#  939: 'persons',
#  940: 'changed',
#  941: 'minebr',
#  942: 'adored',
#  943: 'moving',
#  944: 'amazing',
#  945: 'indie',
#  946: 'recent',
#  947: 'day',
#  948: 'super',
#  949: 'small',
#  950: 'budget',
#  951: 'special',
#  952: 'blow',
#  953: 'away',
#  954: 'alot',
#  955: 'current',
#  956: 'chance',
#  957: 'dragged',
#  958: 'immediately',
#  959: 'audience',
#  960: 'consisted',
#  961: 'mainly',
#  962: 'elderly',
#  963: 'however',
#  964: 'utterly',
#  965: 'fascinating',
#  966: 'targeted',
#  967: 'towards',
#  968: 'believable',
#  969: 'myself',
#  970: 'discussing',
#  971: 'hours',
#  972: 'afterwards',
#  973: 'few',
#  974: 'engrossing',
#  975: 'necessary',
#  976: 'help',
#  977: 'situation',
#  978: 'valuable',
#  979: 'mainstream',
#  980: 'cannot',
#  981: 'prefer',
#  982: 'thrilling',
#  983: 'interesting',
#  984: 'experience',
#  985: 'finished',
#  986: 'min',
#  987: 'version',
#  988: 'widescreen',
#  989: 'friends',
#  990: 'blown',
#  991: 'wont',
#  992: 'bother',
#  993: 'repeating',
#  994: 'others',
#  995: 'do',
#  996: 'concept',
#  997: 'unexpected',
#  998: 'huge',
#  999: 'exhausting',
#  ...}

# %%
window_size = 2
idx_pairs = []
# for each sentence
for sentence in tokenized_corpus:
    indices = [word2idx[word] for word in sentence]
    # for each word, treated as center word
    for center_word_pos in range(len(indices)):
        # for each window position
        for w in range(-window_size, window_size + 1):
            context_word_pos = center_word_pos + w
            # make sure not jump out sentence
            if context_word_pos < 0 or context_word_pos >= len(indices) or center_word_pos == context_word_pos:
                continue
            context_word_idx = indices[context_word_pos]
            idx_pairs.append((indices[center_word_pos], context_word_idx))

idx_pairs = np.array(idx_pairs) # it will be useful to have this as numpy array
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-bcd4b37c912d> in <module>()
#      18
#      19 #saving idx_pairs
# ---> 20 np.save(idx_pairs_array, idx_pairs)
#
# NameError: name 'idx_pairs_array' is not defined

# %%
np.save('idx_pairs.npy', idx_pairs)

# %%
def get_input_layer(word_idx):
    x = torch.zeros(vocabulary_size).float()
    x[word_idx] = 1.0
    return x

# %%
'''
IMPORTS
'''

import torch
from torch.autograd import Variable
import numpy as np
import torch.functional as F
import torch.nn.functional as F

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Assuming that we are on a CUDA machine, this should print a CUDA device:

print(device)
# Out:
# cuda:0

# %%
embedding_dims = 8
W1 = Variable(torch.randn(embedding_dims, vocabulary_size).float(), requires_grad=True)
W2 = Variable(torch.randn(vocabulary_size, embedding_dims).float(), requires_grad=True)
num_epochs = 50
learning_rate = 0.001

W1.to(device)
W2.to(device)

for epo in range(num_epochs):
    loss_val = 0
    for data, target in idx_pairs:
        x = Variable(get_input_layer(data)).float()
        y_true = Variable(torch.from_numpy(np.array([target])).long())

        z1 = torch.matmul(W1, x)
        z2 = torch.matmul(W2, z1)
    
        log_softmax = F.log_softmax(z2, dim=0)

        loss = F.nll_loss(log_softmax.view(1,-1), y_true)
        loss_val += loss.data[0]
        loss.backward()
        W1.data -= learning_rate * W1.grad.data
        W2.data -= learning_rate * W2.grad.data

        W1.grad.data.zero_()
        W2.grad.data.zero_()
    #if epo % 10 == 0:    
    print(f'Loss at epo {epo}: {loss_val/len(idx_pairs)}')
# Out:
# /home/rajaswa-pc/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:22: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-6115a31f1816> in <module>()
#      21         loss = F.nll_loss(log_softmax.view(1,-1), y_true)
#      22         loss_val += loss.data[0]
# ---> 23         loss.backward()
#      24         W1.data -= learning_rate * W1.grad.data
#      25         W2.data -= learning_rate * W2.grad.data
#
# ~/anaconda3/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#      91                 products. Defaults to ``False``.
#      92         """
# ---> 93         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#      94
#      95     def register_hook(self, hook):
#
# ~/anaconda3/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      87     Variable._execution_engine.run_backward(
#      88         tensors, grad_tensors, retain_graph, create_graph,
# ---> 89         allow_unreachable=True)  # allow_unreachable flag
#      90
#      91
#
# KeyboardInterrupt:

# %% [markdown]
# # word2vec example

# %%
'''
IMPORTS
'''

import torch
from torch.autograd import Variable
import numpy as np
import torch.functional as F
import torch.nn.functional as F

# %%
torch.cuda.is_available()

# %%
'''
Defining Corpus
'''

corpus = [
    'he is a king',
    'she is a queen',
    'he is a man',
    'she is a woman',
    'warsaw is poland capital',
    'berlin is germany capital',
    'paris is france capital',   
]

# %%
'''
Tokenizing corpus
'''

def tokenize_corpus(corpus):
    tokens = [x.split() for x in corpus]
    return tokens

tokenized_corpus = tokenize_corpus(corpus)

# %%
tokenized_corpus

# %%
'''
Generating Vocabulary
'''

vocabulary = []
for sentence in tokenized_corpus:
    for token in sentence:
        if token not in vocabulary:
            vocabulary.append(token)

word2idx = {w: idx for (idx, w) in enumerate(vocabulary)}
idx2word = {idx: w for (idx, w) in enumerate(vocabulary)}

vocabulary_size = len(vocabulary)

# %%
word2idx

# %%
idx2word

# %%
window_size = 2
idx_pairs = []
# for each sentence
for sentence in tokenized_corpus:
    indices = [word2idx[word] for word in sentence]
    # for each word, threated as center word
    for center_word_pos in range(len(indices)):
        # for each window position
        for w in range(-window_size, window_size + 1):
            context_word_pos = center_word_pos + w
            # make soure not jump out sentence
            if context_word_pos < 0 or context_word_pos >= len(indices) or center_word_pos == context_word_pos:
                continue
            context_word_idx = indices[context_word_pos]
            idx_pairs.append((indices[center_word_pos], context_word_idx))

idx_pairs = np.array(idx_pairs) # it will be useful to have this as numpy array

# %%
def get_input_layer(word_idx):
    x = torch.zeros(vocabulary_size).float()
    x[word_idx] = 1.0
    return x

# %%
embedding_dims = 5
W1 = Variable(torch.randn(embedding_dims, vocabulary_size).float(), requires_grad=True)
W2 = Variable(torch.randn(vocabulary_size, embedding_dims).float(), requires_grad=True)
num_epochs = 101
learning_rate = 0.001

for epo in range(num_epochs):
    loss_val = 0
    for data, target in idx_pairs:
        x = Variable(get_input_layer(data)).float()
        y_true = Variable(torch.from_numpy(np.array([target])).long())

        z1 = torch.matmul(W1, x)
        z2 = torch.matmul(W2, z1)
    
        log_softmax = F.log_softmax(z2, dim=0)

        loss = F.nll_loss(log_softmax.view(1,-1), y_true)
        loss_val += loss.data[0]
        loss.backward()
        W1.data -= learning_rate * W1.grad.data
        W2.data -= learning_rate * W2.grad.data

        W1.grad.data.zero_()
        W2.grad.data.zero_()
    if epo % 10 == 0:    
        print(f'Loss at epo {epo}: {loss_val/len(idx_pairs)}')

# %%
W1.data

# %%
W2.data
